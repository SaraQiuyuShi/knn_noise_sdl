# %%
import pandas as pd
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from xgboost import XGBRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import RandomizedSearchCV

random_state = 42

# %%
# I assume that the data is already preprocessed and ready to be used
X = pd.read_csv('X_formation_energy_union_features.csv',index_col=0)
y = pd.read_csv('y_formation_energy.csv',index_col=0)
# turn y into a 1D array
y = y.iloc[:,0]

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=random_state)

# %%
X
# Out:
#               mean neighbor distance variation  MagpieData mode NsValence  \
# jid
# JVASP-90856                           0.064699                        1.0
# JVASP-86097                           0.200279                        2.0
# JVASP-64906                           0.011565                        2.0
# JVASP-98225                           0.071601                        1.0
# JVASP-10                              0.119720                        2.0
# ...                                        ...                        ...
# JVASP-156020                          0.112164                        1.0
# JVASP-156398                          0.046326                        2.0
# JVASP-156099                          0.109214                        2.0
# JVASP-156007                          0.100676                        2.0
# JVASP-156008                          0.109130                        1.0
#
#               MagpieData maximum SpaceGroupNumber  \
# jid
# JVASP-90856                                 227.0
# JVASP-86097                                 194.0
# JVASP-64906                                 194.0
# JVASP-98225                                 229.0
# JVASP-10                                    229.0
# ...                                           ...
# JVASP-156020                                225.0
# JVASP-156398                                194.0
# JVASP-156099                                229.0
# JVASP-156007                                227.0
# JVASP-156008                                225.0
#
#               MagpieData maximum MendeleevNumber  \
# jid
# JVASP-90856                                 84.0
# JVASP-86097                                 72.0
# JVASP-64906                                 67.0
# JVASP-98225                                 86.0
# JVASP-10                                    89.0
# ...                                          ...
# JVASP-156020                                81.0
# JVASP-156398                                76.0
# JVASP-156099                                86.0
# JVASP-156007                                78.0
# JVASP-156008                                80.0
#
#               avg_dev local difference in CovalentRadius  compound possible  \
# jid
# JVASP-90856                                     9.730249              False
# JVASP-86097                                    19.976881              False
# JVASP-64906                                     0.500000              False
# JVASP-98225                                     1.528927              False
# JVASP-10                                        7.657251              False
# ...                                                  ...                ...
# JVASP-156020                                   14.515769              False
# JVASP-156398                                    9.002206              False
# JVASP-156099                                   15.511391              False
# JVASP-156007                                    9.547456              False
# JVASP-156008                                   12.568482              False
#
#               MagpieData range NdValence  MagpieData mean Column  \
# jid
# JVASP-90856                         10.0               11.000000
# JVASP-86097                          0.0               11.571429
# JVASP-64906                          7.0                5.000000
# JVASP-98225                         10.0                8.000000
# JVASP-10                             7.0               12.333333
# ...                                  ...                     ...
# JVASP-156020                         9.0                9.800000
# JVASP-156398                        10.0                9.333333
# JVASP-156099                        10.0               11.600000
# JVASP-156007                         5.0                9.000000
# JVASP-156008                         8.0                9.400000
#
#               mean local difference in Electronegativity  \
# jid
# JVASP-90856                                     0.316376
# JVASP-86097                                     0.278830
# JVASP-64906                                     0.408989
# JVASP-98225                                     0.827830
# JVASP-10                                        0.487429
# ...                                                  ...
# JVASP-156020                                    0.531222
# JVASP-156398                                    0.357266
# JVASP-156099                                    0.522216
# JVASP-156007                                    0.272436
# JVASP-156008                                    0.431561
#
#               minimum local difference in GSbandgap  ...  \
# jid                                                  ...
# JVASP-90856                                0.000000  ...
# JVASP-86097                                0.353776  ...
# JVASP-64906                                0.000000  ...
# JVASP-98225                                0.000000  ...
# JVASP-10                                   0.284273  ...
# ...                                             ...  ...
# JVASP-156020                               0.000000  ...
# JVASP-156398                               0.000000  ...
# JVASP-156099                               0.000000  ...
# JVASP-156007                               0.406256  ...
# JVASP-156008                               0.000000  ...
#
#               range local difference in SpaceGroupNumber  \
# jid
# JVASP-90856                                    23.850694
# JVASP-86097                                    21.148365
# JVASP-64906                                     0.000000
# JVASP-98225                                    21.640334
# JVASP-10                                      112.248335
# ...                                                  ...
# JVASP-156020                                    0.000000
# JVASP-156398                                    0.000000
# JVASP-156099                                   76.048553
# JVASP-156007                                   10.277844
# JVASP-156008                                   19.011876
#
#               maximum CN_VoronoiNN  MagpieData range Column  \
# jid
# JVASP-90856              10.623333                     11.0
# JVASP-86097              24.598746                     10.0
# JVASP-64906              11.982697                      6.0
# JVASP-98225              12.260669                     14.0
# JVASP-10                 11.168806                     11.0
# ...                            ...                      ...
# JVASP-156020             18.191019                     11.0
# JVASP-156398              9.971808                     10.0
# JVASP-156099             16.143290                     13.0
# JVASP-156007             17.295015                     11.0
# JVASP-156008             17.998458                     11.0
#
#               MagpieData mean MeltingT  MagpieData maximum MeltingT  \
# jid
# JVASP-90856                1518.942500                       1941.0
# JVASP-86097                2253.285714                       2348.0
# JVASP-64906                2258.250000                       3306.0
# JVASP-98225                 440.465000                        544.4
# JVASP-10                   1057.000000                       2183.0
# ...                                ...                          ...
# JVASP-156020               1399.644000                       2237.0
# JVASP-156398                824.560000                       1204.0
# JVASP-156099                589.660000                       1000.0
# JVASP-156007               2010.400000                       2430.0
# JVASP-156008               1649.432000                       2607.0
#
#               MagpieData mode NUnfilled  frac p valence electrons  \
# jid
# JVASP-90856                         1.0                  0.147059
# JVASP-86097                         5.0                  0.200000
# JVASP-64906                         0.0                  0.000000
# JVASP-98225                         1.0                  0.100000
# JVASP-10                            2.0                  0.216216
# ...                                 ...                       ...
# JVASP-156020                        3.0                  0.051948
# JVASP-156398                        0.0                  0.022727
# JVASP-156099                        3.0                  0.093023
# JVASP-156007                        4.0                  0.108108
# JVASP-156008                        4.0                  0.083333
#
#               MagpieData minimum GSbandgap  \
# jid
# JVASP-90856                            0.0
# JVASP-86097                            0.0
# JVASP-64906                            0.0
# JVASP-98225                            0.0
# JVASP-10                               0.0
# ...                                    ...
# JVASP-156020                           0.0
# JVASP-156398                           0.0
# JVASP-156099                           0.0
# JVASP-156007                           0.0
# JVASP-156008                           0.0
#
#               minimum local difference in Column  MagpieData mode NpUnfilled
# jid
# JVASP-90856                             2.606183                         0.0
# JVASP-86097                             2.321363                         5.0
# JVASP-64906                             3.895137                         0.0
# JVASP-98225                             8.792858                         0.0
# JVASP-10                                3.913647                         2.0
# ...                                          ...                         ...
# JVASP-156020                            4.447399                         0.0
# JVASP-156398                            5.000000                         0.0
# JVASP-156099                            3.533003                         3.0
# JVASP-156007                            4.674021                         0.0
# JVASP-156008                            4.687408                         0.0
#
# [71571 rows x 47 columns]

# %%
y
# Out:
# jid
# JVASP-90856    -0.42762
# JVASP-86097    -0.41596
# JVASP-64906     0.04847
# JVASP-98225    -0.44140
# JVASP-10       -0.71026
#                  ...
# JVASP-156020   -0.30652
# JVASP-156398   -0.34112
# JVASP-156099   -0.39352
# JVASP-156007   -0.54853
# JVASP-156008   -0.28045
# Name: formation_energy_peratom, Length: 71571, dtype: float64

# %% [markdown]
# # RFR

# %%
# define the hyperparameter grid to search
param_grid = {
    'n_estimators': [300, 500, 700, 900],
    'max_depth': [100, 200, 300],
    'max_features': [0.4],
    'bootstrap': [False],
    'min_samples_split': [ 3, 5, 7, 9],
    'min_samples_leaf': [1, 2, 3, 4, 5],
}

# define the model
rf = RandomForestRegressor(random_state=random_state,n_jobs=-1)

# define the search, using 5-fold cross-validation within the training set
search = RandomizedSearchCV(
    rf,
    param_grid,
    scoring='neg_mean_squared_error',
    n_jobs=-1,
    cv=5,
    verbose=3,
    random_state=random_state,
    n_iter=100
    )

# perform the search
search.fit(X_train, y_train)

# save the results of the search to csv
results = pd.DataFrame(search.cv_results_)
results.to_csv('rf_hyperparameter_tuning.csv')

# summarize the best score and configuration
print("Best: %f using %s" % (search.best_score_, search.best_params_))

# train the model with the best hyperparameters
best_rf = search.best_estimator_
best_rf.fit(X_train, y_train)

# evaluate the model using MAE, RMSE and R2
y_pred_rf = best_rf.predict(X_test)
print('MAE:', mean_absolute_error(y_test, y_pred_rf))
print('RMSE:', mean_squared_error(y_test, y_pred_rf, squared=False))
print('R2:', r2_score(y_test, y_pred_rf))

df_y_rf = pd.DataFrame({'y_test':y_test, 'y_pred_rf':y_pred_rf})
df_y_rf.to_csv('rf_y_test_y_pred.csv')
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits

# %%
best_rf
# save the model 
import joblib
joblib.dump(best_rf, 'rf_formation_energy_model.pkl')
# Out:
# RandomForestRegressor(bootstrap=False, max_depth=100, max_features=0.4,
#                       n_estimators=500, n_jobs=-1, random_state=42)

# %% [markdown]
# # XGB

# %%
# define the hyperparameter grid to search
param_grid = {
    'n_estimators': [500, 600, 700],
    'max_depth': [ 10],
    'learning_rate': [0.05, 0.1],
    'subsample': [ 0.9],
    'colsample_bytree': [ 0.5, 0.7, 0.9],
}

# define the model
xgb = XGBRegressor(random_state=random_state,
                   n_jobs=-1,
                   )

# define the search, using 5-fold cross-validation within the training set

search = RandomizedSearchCV(
    xgb,
    param_distributions=param_grid,
    scoring='neg_mean_squared_error',
    n_jobs=-1,
    cv=5,
    n_iter=100,  # Number of parameter settings sampled
    verbose=3,
    random_state=random_state
)

# perform the search
search.fit(X_train, y_train)

# save the results of the search to csv
results = pd.DataFrame(search.cv_results_)

results.to_csv('xgb_hyperparameter_tuning.csv')

# summarize the best score and configuration
print("Best: %f using %s" % (search.best_score_, search.best_params_))

# train the model with the best hyperparameters
best_xgb = search.best_estimator_
best_xgb.fit(X_train, y_train)

# evaluate the model using MAE, RMSE and R2
y_pred_xgb = best_xgb.predict(X_test)
print('MAE:', mean_absolute_error(y_test, y_pred_xgb))
print('RMSE:', mean_squared_error(y_test, y_pred_xgb, squared=False))
print('R2:', r2_score(y_test, y_pred_xgb))

df_y_xgb = pd.DataFrame({'y_test':y_test, 'y_pred_xgb':y_pred_xgb})
df_y_xgb.to_csv('xgb_y_test_y_pred.csv')
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV 2/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=500, subsample=0.5;, score=-0.039 total time=  13.7s
# [CV 3/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=500, subsample=0.5;, score=-0.038 total time=  13.8s
# [CV 4/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=500, subsample=0.5;, score=-0.032 total time=  14.0s
# [CV 1/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=500, subsample=0.5;, score=-0.039 total time=  15.9s
# [CV 5/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=500, subsample=0.5;, score=-0.039 total time=  17.3s
# [CV 4/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=10, n_estimators=600, subsample=0.9;, score=-0.030 total time=  21.1s
# [CV 2/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=10, n_estimators=600, subsample=0.9;, score=-0.037 total time=  21.3s
# [CV 3/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=10, n_estimators=600, subsample=0.9;, score=-0.037 total time=  21.4s
# [CV 1/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=10, n_estimators=600, subsample=0.9;, score=-0.037 total time=  23.6s
# [CV 5/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=10, n_estimators=600, subsample=0.9;, score=-0.037 total time=  23.7s
# [CV 2/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=400, subsample=0.3;, score=-0.044 total time=   8.2s
# [CV 1/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=400, subsample=0.3;, score=-0.044 total time=   8.9s
# [CV 3/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=400, subsample=0.3;, score=-0.041 total time=   7.2s
# [CV 4/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=400, subsample=0.3;, score=-0.039 total time=   7.2s
# [CV 1/5] END colsample_bytree=0.3, learning_rate=0.2, max_depth=None, n_estimators=100, subsample=0.1;, score=-0.087 total time=   0.9s
# [CV 2/5] END colsample_bytree=0.3, learning_rate=0.2, max_depth=None, n_estimators=100, subsample=0.1;, score=-0.093 total time=   0.8s
# [CV 3/5] END colsample_bytree=0.3, learning_rate=0.2, max_depth=None, n_estimators=100, subsample=0.1;, score=-0.083 total time=   0.9s
# [CV 4/5] END colsample_bytree=0.3, learning_rate=0.2, max_depth=None, n_estimators=100, subsample=0.1;, score=-0.079 total time=   0.8s
# [CV 5/5] END colsample_bytree=0.3, learning_rate=0.2, max_depth=None, n_estimators=100, subsample=0.1;, score=-0.088 total time=   0.8s
# [CV 5/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=400, subsample=0.3;, score=-0.044 total time=   7.2s
# [CV 4/5] END colsample_bytree=0.5, learning_rate=0.1, max_depth=500, n_estimators=200, subsample=0.9;, score=-0.038 total time= 4.3min
# [CV 3/5] END colsample_bytree=0.5, learning_rate=0.1, max_depth=500, n_estimators=200, subsample=0.9;, score=-0.045 total time= 4.3min
# [CV 5/5] END colsample_bytree=0.5, learning_rate=0.1, max_depth=500, n_estimators=200, subsample=0.9;, score=-0.047 total time= 4.5min
# [CV 2/5] END colsample_bytree=0.5, learning_rate=0.1, max_depth=500, n_estimators=200, subsample=0.9;, score=-0.046 total time= 4.6min
# [CV 1/5] END colsample_bytree=0.5, learning_rate=0.1, max_depth=500, n_estimators=200, subsample=0.9;, score=-0.046 total time= 5.2min
# [CV 1/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=500, n_estimators=500, subsample=0.5;, score=-0.044 total time= 6.5min
# [CV 2/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=500, n_estimators=500, subsample=0.5;, score=-0.044 total time= 6.6min
# [CV 1/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=100, n_estimators=400, subsample=1;, score=-0.044 total time= 6.8min
# [CV 4/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=500, n_estimators=500, subsample=0.5;, score=-0.037 total time= 7.3min
# [CV 1/5] END colsample_bytree=0.7, learning_rate=0.2, max_depth=10, n_estimators=200, subsample=1;, score=-0.043 total time=   7.6s
# [CV 3/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=500, n_estimators=500, subsample=0.5;, score=-0.045 total time= 7.5min
# [CV 2/5] END colsample_bytree=0.7, learning_rate=0.2, max_depth=10, n_estimators=200, subsample=1;, score=-0.042 total time=   7.3s
# [CV 2/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=100, n_estimators=400, subsample=1;, score=-0.043 total time= 7.0min
# [CV 1/5] END colsample_bytree=0.3, learning_rate=0.2, max_depth=100, n_estimators=400, subsample=0.9;, score=-0.058 total time= 2.9min
# [CV 5/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=500, n_estimators=500, subsample=0.5;, score=-0.045 total time= 7.6min
# [CV 3/5] END colsample_bytree=0.7, learning_rate=0.2, max_depth=10, n_estimators=200, subsample=1;, score=-0.043 total time=   7.6s
# [CV 4/5] END colsample_bytree=0.7, learning_rate=0.2, max_depth=10, n_estimators=200, subsample=1;, score=-0.035 total time=   7.6s
# [CV 5/5] END colsample_bytree=0.7, learning_rate=0.2, max_depth=10, n_estimators=200, subsample=1;, score=-0.043 total time=   7.8s
# [CV 2/5] END colsample_bytree=0.3, learning_rate=0.2, max_depth=100, n_estimators=400, subsample=0.9;, score=-0.058 total time= 2.5min
# [CV 1/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=300, subsample=1;, score=-0.040 total time=   8.7s
# [CV 2/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=300, subsample=1;, score=-0.040 total time=   8.8s
# [CV 3/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=300, subsample=1;, score=-0.039 total time=   9.0s
# [CV 4/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=300, subsample=1;, score=-0.033 total time=   8.8s
# [CV 5/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=300, subsample=1;, score=-0.042 total time=   9.0s
# [CV 1/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=500, subsample=0.1;, score=-0.054 total time=   9.1s
# [CV 2/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=500, subsample=0.1;, score=-0.054 total time=   8.8s
# [CV 3/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=500, subsample=0.1;, score=-0.050 total time=   9.4s
# [CV 4/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=500, subsample=0.1;, score=-0.048 total time=   9.2s
# [CV 5/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=500, subsample=0.1;, score=-0.055 total time=   9.7s
# [CV 1/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=100, n_estimators=200, subsample=0.3;, score=-0.048 total time= 1.3min
# [CV 2/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=100, n_estimators=200, subsample=0.3;, score=-0.050 total time= 1.3min
# [CV 3/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=100, n_estimators=200, subsample=0.3;, score=-0.046 total time= 1.3min
# [CV 5/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=100, n_estimators=200, subsample=0.3;, score=-0.050 total time= 1.2min
# [CV 4/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=100, n_estimators=200, subsample=0.3;, score=-0.043 total time= 1.3min
# [CV 1/5] END colsample_bytree=0.7, learning_rate=0.2, max_depth=None, n_estimators=600, subsample=1;, score=-0.041 total time=   5.0s
# [CV 2/5] END colsample_bytree=0.7, learning_rate=0.2, max_depth=None, n_estimators=600, subsample=1;, score=-0.043 total time=   5.2s
# [CV 3/5] END colsample_bytree=0.3, learning_rate=0.2, max_depth=100, n_estimators=400, subsample=0.9;, score=-0.055 total time= 3.1min
# [CV 3/5] END colsample_bytree=0.7, learning_rate=0.2, max_depth=None, n_estimators=600, subsample=1;, score=-0.040 total time=   5.1s
# [CV 4/5] END colsample_bytree=0.7, learning_rate=0.2, max_depth=None, n_estimators=600, subsample=1;, score=-0.035 total time=   5.3s
# [CV 4/5] END colsample_bytree=0.3, learning_rate=0.2, max_depth=100, n_estimators=400, subsample=0.9;, score=-0.049 total time= 3.0min
# [CV 5/5] END colsample_bytree=0.7, learning_rate=0.2, max_depth=None, n_estimators=600, subsample=1;, score=-0.040 total time=   5.1s
# [CV 1/5] END colsample_bytree=0.5, learning_rate=0.2, max_depth=None, n_estimators=500, subsample=0.5;, score=-0.045 total time=   4.1s
# [CV 2/5] END colsample_bytree=0.5, learning_rate=0.2, max_depth=None, n_estimators=500, subsample=0.5;, score=-0.048 total time=   3.9s
# [CV 3/5] END colsample_bytree=0.5, learning_rate=0.2, max_depth=None, n_estimators=500, subsample=0.5;, score=-0.044 total time=   3.8s
# [CV 1/5] END colsample_bytree=0.7, learning_rate=0.2, max_depth=None, n_estimators=100, subsample=0.7;, score=-0.058 total time=   1.1s
# [CV 2/5] END colsample_bytree=0.7, learning_rate=0.2, max_depth=None, n_estimators=100, subsample=0.7;, score=-0.061 total time=   1.1s
# [CV 4/5] END colsample_bytree=0.5, learning_rate=0.2, max_depth=None, n_estimators=500, subsample=0.5;, score=-0.041 total time=   3.8s
# [CV 5/5] END colsample_bytree=0.5, learning_rate=0.2, max_depth=None, n_estimators=500, subsample=0.5;, score=-0.045 total time=   4.0s
# [CV 3/5] END colsample_bytree=0.7, learning_rate=0.2, max_depth=None, n_estimators=100, subsample=0.7;, score=-0.058 total time=   1.1s
# [CV 4/5] END colsample_bytree=0.7, learning_rate=0.2, max_depth=None, n_estimators=100, subsample=0.7;, score=-0.053 total time=   1.2s
# [CV 5/5] END colsample_bytree=0.7, learning_rate=0.2, max_depth=None, n_estimators=100, subsample=0.7;, score=-0.057 total time=   1.2s
# [CV 1/5] END colsample_bytree=0.3, learning_rate=0.05, max_depth=5, n_estimators=600, subsample=0.7;, score=-0.055 total time=   3.7s
# [CV 2/5] END colsample_bytree=0.3, learning_rate=0.05, max_depth=5, n_estimators=600, subsample=0.7;, score=-0.057 total time=   3.6s
# [CV 3/5] END colsample_bytree=0.3, learning_rate=0.05, max_depth=5, n_estimators=600, subsample=0.7;, score=-0.055 total time=   3.7s
# [CV 4/5] END colsample_bytree=0.3, learning_rate=0.05, max_depth=5, n_estimators=600, subsample=0.7;, score=-0.050 total time=   3.7s
# [CV 5/5] END colsample_bytree=0.3, learning_rate=0.05, max_depth=5, n_estimators=600, subsample=0.7;, score=-0.055 total time=   3.7s
# [CV 1/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=400, subsample=0.5;, score=-0.040 total time=  12.5s
# [CV 2/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=400, subsample=0.5;, score=-0.039 total time=  11.5s
# [CV 3/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=400, subsample=0.5;, score=-0.039 total time=  11.6s
# [CV 1/5] END colsample_bytree=0.3, learning_rate=0.2, max_depth=None, n_estimators=200, subsample=0.1;, score=-0.082 total time=   1.7s
# [CV 2/5] END colsample_bytree=0.3, learning_rate=0.2, max_depth=None, n_estimators=200, subsample=0.1;, score=-0.085 total time=   1.6s
# [CV 3/5] END colsample_bytree=0.3, learning_rate=0.2, max_depth=None, n_estimators=200, subsample=0.1;, score=-0.079 total time=   1.7s
# [CV 4/5] END colsample_bytree=0.3, learning_rate=0.2, max_depth=None, n_estimators=200, subsample=0.1;, score=-0.074 total time=   1.6s
# [CV 5/5] END colsample_bytree=0.3, learning_rate=0.2, max_depth=None, n_estimators=200, subsample=0.1;, score=-0.081 total time=   1.7s
# [CV 4/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=400, subsample=0.5;, score=-0.032 total time=  12.0s
# [CV 5/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=400, subsample=0.5;, score=-0.039 total time=  14.0s
# [CV 5/5] END colsample_bytree=0.3, learning_rate=0.2, max_depth=100, n_estimators=400, subsample=0.9;, score=-0.059 total time= 2.8min
# [CV 4/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=100, n_estimators=400, subsample=1;, score=-0.037 total time= 7.5min
# [CV 3/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=100, n_estimators=400, subsample=1;, score=-0.044 total time= 7.7min
# [CV 5/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=100, n_estimators=400, subsample=1;, score=-0.044 total time= 7.6min
# [CV 2/5] END colsample_bytree=0.3, learning_rate=0.2, max_depth=50, n_estimators=300, subsample=0.7;, score=-0.058 total time= 3.9min
# [CV 1/5] END colsample_bytree=0.3, learning_rate=0.2, max_depth=50, n_estimators=300, subsample=0.7;, score=-0.056 total time= 4.1min
# [CV 5/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=500, n_estimators=600, subsample=1;, score=-0.044 total time= 7.9min
# [CV 2/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=500, n_estimators=600, subsample=1;, score=-0.043 total time= 8.0min
# [CV 1/5] END colsample_bytree=0.3, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=0.7;, score=-0.039 total time=  12.2s
# [CV 2/5] END colsample_bytree=0.3, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=0.7;, score=-0.039 total time=  12.0s
# [CV 3/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=500, n_estimators=600, subsample=1;, score=-0.044 total time= 8.5min
# [CV 4/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=500, n_estimators=600, subsample=1;, score=-0.037 total time= 8.5min
# [CV 3/5] END colsample_bytree=0.3, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=0.7;, score=-0.036 total time=  12.1s
# [CV 1/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=500, n_estimators=600, subsample=1;, score=-0.044 total time= 9.1min
# [CV 4/5] END colsample_bytree=0.3, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=0.7;, score=-0.033 total time=  12.7s
# [CV 5/5] END colsample_bytree=0.3, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=0.7;, score=-0.040 total time=  13.0s
# [CV 3/5] END colsample_bytree=0.3, learning_rate=0.2, max_depth=50, n_estimators=300, subsample=0.7;, score=-0.054 total time= 3.8min
# [CV 4/5] END colsample_bytree=0.3, learning_rate=0.2, max_depth=50, n_estimators=300, subsample=0.7;, score=-0.049 total time= 3.9min
# [CV 5/5] END colsample_bytree=0.3, learning_rate=0.2, max_depth=50, n_estimators=300, subsample=0.7;, score=-0.058 total time= 3.9min
# [CV 1/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=50, n_estimators=300, subsample=0.3;, score=-0.041 total time= 1.8min
# [CV 2/5] END colsample_bytree=0.3, learning_rate=0.05, max_depth=50, n_estimators=500, subsample=0.7;, score=-0.046 total time=12.1min
# [CV 1/5] END colsample_bytree=0.3, learning_rate=0.05, max_depth=50, n_estimators=500, subsample=0.7;, score=-0.047 total time=12.5min
# [CV 2/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=50, n_estimators=300, subsample=0.3;, score=-0.040 total time= 1.8min
# [CV 1/5] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=300, subsample=0.9;, score=-0.040 total time=  10.9s
# [CV 2/5] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=300, subsample=0.9;, score=-0.039 total time=  10.4s
# [CV 3/5] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=300, subsample=0.9;, score=-0.038 total time=  11.3s
# [CV 3/5] END colsample_bytree=0.5, learning_rate=0.1, max_depth=500, n_estimators=200, subsample=0.7;, score=-0.044 total time= 5.6min
# [CV 4/5] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=300, subsample=0.9;, score=-0.033 total time=  12.4s
# [CV 1/5] END colsample_bytree=0.5, learning_rate=0.1, max_depth=500, n_estimators=200, subsample=0.7;, score=-0.047 total time= 5.9min
# [CV 5/5] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=300, subsample=0.9;, score=-0.039 total time=  12.6s
# [CV 2/5] END colsample_bytree=0.5, learning_rate=0.1, max_depth=500, n_estimators=200, subsample=0.7;, score=-0.045 total time= 5.9min
# python(42114) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# [CV 5/5] END colsample_bytree=0.3, learning_rate=0.05, max_depth=50, n_estimators=500, subsample=0.7;, score=-0.048 total time=11.7min
# python(42115) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# [CV 4/5] END colsample_bytree=0.5, learning_rate=0.1, max_depth=500, n_estimators=200, subsample=0.7;, score=-0.039 total time= 5.9min
# python(42118) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# [CV 3/5] END colsample_bytree=0.3, learning_rate=0.05, max_depth=50, n_estimators=500, subsample=0.7;, score=-0.045 total time=13.6min
# python(42120) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# [CV 4/5] END colsample_bytree=0.3, learning_rate=0.05, max_depth=50, n_estimators=500, subsample=0.7;, score=-0.040 total time=13.7min
# [CV 1/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=None, n_estimators=600, subsample=0.3;, score=-0.048 total time=   4.5s
# python(42122) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# [CV 3/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=50, n_estimators=300, subsample=0.3;, score=-0.039 total time= 2.0min
# python(42123) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# [CV 2/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=None, n_estimators=600, subsample=0.3;, score=-0.047 total time=   4.5s
# [CV 3/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=None, n_estimators=600, subsample=0.3;, score=-0.046 total time=   4.5s
# [CV 4/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=None, n_estimators=600, subsample=0.3;, score=-0.042 total time=   4.7s
# [CV 5/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=None, n_estimators=600, subsample=0.3;, score=-0.047 total time=   4.8s
# [CV 5/5] END colsample_bytree=0.5, learning_rate=0.1, max_depth=500, n_estimators=200, subsample=0.7;, score=-0.047 total time= 4.1min
# python(42159) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# [CV 4/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=50, n_estimators=300, subsample=0.3;, score=-0.033 total time= 2.0min
# [CV 1/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=100, n_estimators=300, subsample=0.1;, score=-0.046 total time=  51.5s
# [CV 2/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=100, n_estimators=300, subsample=0.1;, score=-0.046 total time=  50.9s
# [CV 3/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=100, n_estimators=300, subsample=0.1;, score=-0.042 total time=  51.3s
# [CV 5/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=100, n_estimators=300, subsample=0.1;, score=-0.042 total time=  50.9s
# [CV 4/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=100, n_estimators=300, subsample=0.1;, score=-0.039 total time=  51.3s
# [CV 5/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=50, n_estimators=300, subsample=0.3;, score=-0.040 total time= 2.1min
# [CV 1/5] END colsample_bytree=0.3, learning_rate=0.05, max_depth=5, n_estimators=400, subsample=0.5;, score=-0.064 total time=   2.5s
# [CV 2/5] END colsample_bytree=0.3, learning_rate=0.05, max_depth=5, n_estimators=400, subsample=0.5;, score=-0.067 total time=   2.5s
# [CV 3/5] END colsample_bytree=0.3, learning_rate=0.05, max_depth=5, n_estimators=400, subsample=0.5;, score=-0.064 total time=   2.4s
# [CV 4/5] END colsample_bytree=0.3, learning_rate=0.05, max_depth=5, n_estimators=400, subsample=0.5;, score=-0.059 total time=   2.5s
# [CV 5/5] END colsample_bytree=0.3, learning_rate=0.05, max_depth=5, n_estimators=400, subsample=0.5;, score=-0.064 total time=   2.4s
# [CV 1/5] END colsample_bytree=0.7, learning_rate=0.2, max_depth=10, n_estimators=100, subsample=0.5;, score=-0.049 total time=   3.2s
# [CV 2/5] END colsample_bytree=0.7, learning_rate=0.2, max_depth=10, n_estimators=100, subsample=0.5;, score=-0.049 total time=   3.0s
# [CV 3/5] END colsample_bytree=0.7, learning_rate=0.2, max_depth=10, n_estimators=100, subsample=0.5;, score=-0.046 total time=   3.1s
# [CV 4/5] END colsample_bytree=0.7, learning_rate=0.2, max_depth=10, n_estimators=100, subsample=0.5;, score=-0.041 total time=   3.0s
# [CV 5/5] END colsample_bytree=0.7, learning_rate=0.2, max_depth=10, n_estimators=100, subsample=0.5;, score=-0.048 total time=   3.2s
# [CV 1/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=100, n_estimators=100, subsample=0.5;, score=-0.046 total time=  48.5s
# [CV 2/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=100, n_estimators=100, subsample=0.5;, score=-0.045 total time=  48.4s
# [CV 3/5] END colsample_bytree=0.5, learning_rate=0.2, max_depth=500, n_estimators=600, subsample=0.5;, score=-0.051 total time= 1.2min
# [CV 4/5] END colsample_bytree=0.5, learning_rate=0.2, max_depth=500, n_estimators=600, subsample=0.5;, score=-0.046 total time= 1.4min
# [CV 1/5] END colsample_bytree=0.7, learning_rate=0.2, max_depth=5, n_estimators=300, subsample=0.9;, score=-0.050 total time=   2.1s
# [CV 2/5] END colsample_bytree=0.7, learning_rate=0.2, max_depth=5, n_estimators=300, subsample=0.9;, score=-0.052 total time=   2.1s
# [CV 3/5] END colsample_bytree=0.7, learning_rate=0.2, max_depth=5, n_estimators=300, subsample=0.9;, score=-0.048 total time=   2.1s
# [CV 4/5] END colsample_bytree=0.7, learning_rate=0.2, max_depth=5, n_estimators=300, subsample=0.9;, score=-0.043 total time=   2.0s
# [CV 5/5] END colsample_bytree=0.7, learning_rate=0.2, max_depth=5, n_estimators=300, subsample=0.9;, score=-0.049 total time=   2.1s
# [CV 3/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=100, n_estimators=100, subsample=0.5;, score=-0.044 total time=  44.9s
# [CV 5/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=100, n_estimators=100, subsample=0.5;, score=-0.045 total time=  44.2s
# [CV 4/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=100, n_estimators=100, subsample=0.5;, score=-0.037 total time=  45.7s
# [CV 1/5] END colsample_bytree=0.5, learning_rate=0.2, max_depth=500, n_estimators=600, subsample=0.5;, score=-0.053 total time= 3.3min
# [CV 5/5] END colsample_bytree=0.5, learning_rate=0.2, max_depth=500, n_estimators=600, subsample=0.5;, score=-0.053 total time= 3.6min
# [CV 1/5] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.3;, score=-0.068 total time=   1.6s
# [CV 2/5] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.3;, score=-0.070 total time=   1.4s
# [CV 3/5] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.3;, score=-0.067 total time=   1.5s
# [CV 4/5] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.3;, score=-0.063 total time=   1.5s
# [CV 5/5] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.3;, score=-0.067 total time=   1.7s
# [CV 2/5] END colsample_bytree=0.5, learning_rate=0.2, max_depth=500, n_estimators=600, subsample=0.5;, score=-0.055 total time= 4.1min
# [CV 4/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=50, n_estimators=500, subsample=0.7;, score=-0.043 total time= 6.4min
# [CV 1/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=50, n_estimators=500, subsample=0.7;, score=-0.052 total time= 6.5min
# [CV 1/5] END colsample_bytree=0.5, learning_rate=0.1, max_depth=100, n_estimators=500, subsample=0.3;, score=-0.046 total time= 2.2min
# [CV 5/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=50, n_estimators=500, subsample=0.7;, score=-0.051 total time= 6.5min
# [CV 2/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=50, n_estimators=500, subsample=0.7;, score=-0.049 total time= 6.6min
# [CV 3/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=50, n_estimators=500, subsample=0.7;, score=-0.048 total time= 6.6min
# [CV 2/5] END colsample_bytree=0.5, learning_rate=0.1, max_depth=100, n_estimators=500, subsample=0.3;, score=-0.046 total time= 2.2min
# [CV 1/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=50, n_estimators=200, subsample=0.7;, score=-0.044 total time= 4.7min
# [CV 4/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=50, n_estimators=200, subsample=0.7;, score=-0.038 total time= 4.4min
# [CV 3/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=50, n_estimators=200, subsample=0.7;, score=-0.045 total time= 4.5min
# [CV 1/5] END colsample_bytree=0.5, learning_rate=0.2, max_depth=5, n_estimators=400, subsample=0.9;, score=-0.046 total time=   3.3s
# [CV 2/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=50, n_estimators=200, subsample=0.7;, score=-0.044 total time= 4.6min
# [CV 2/5] END colsample_bytree=0.5, learning_rate=0.2, max_depth=5, n_estimators=400, subsample=0.9;, score=-0.049 total time=   3.2s
# [CV 3/5] END colsample_bytree=0.5, learning_rate=0.2, max_depth=5, n_estimators=400, subsample=0.9;, score=-0.045 total time=   3.0s
# [CV 4/5] END colsample_bytree=0.5, learning_rate=0.2, max_depth=5, n_estimators=400, subsample=0.9;, score=-0.043 total time=   3.1s
# [CV 5/5] END colsample_bytree=0.5, learning_rate=0.2, max_depth=5, n_estimators=400, subsample=0.9;, score=-0.046 total time=   2.8s
# [CV 5/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=50, n_estimators=200, subsample=0.7;, score=-0.046 total time= 3.6min
# [CV 3/5] END colsample_bytree=0.5, learning_rate=0.1, max_depth=100, n_estimators=500, subsample=0.3;, score=-0.043 total time= 2.4min
# [CV 4/5] END colsample_bytree=0.5, learning_rate=0.1, max_depth=100, n_estimators=500, subsample=0.3;, score=-0.038 total time= 2.4min
# [CV 5/5] END colsample_bytree=0.5, learning_rate=0.1, max_depth=100, n_estimators=500, subsample=0.3;, score=-0.046 total time= 2.3min
# [CV 1/5] END colsample_bytree=0.5, learning_rate=0.2, max_depth=10, n_estimators=300, subsample=0.3;, score=-0.053 total time=   7.4s
# [CV 2/5] END colsample_bytree=0.5, learning_rate=0.2, max_depth=10, n_estimators=300, subsample=0.3;, score=-0.053 total time=   6.7s
# [CV 3/5] END colsample_bytree=0.5, learning_rate=0.2, max_depth=10, n_estimators=300, subsample=0.3;, score=-0.048 total time=   6.6s
# [CV 4/5] END colsample_bytree=0.5, learning_rate=0.2, max_depth=10, n_estimators=300, subsample=0.3;, score=-0.045 total time=   6.8s
# [CV 1/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=None, n_estimators=100, subsample=0.1;, score=-0.080 total time=   1.1s
# [CV 2/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=None, n_estimators=100, subsample=0.1;, score=-0.083 total time=   1.0s
# [CV 3/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=None, n_estimators=100, subsample=0.1;, score=-0.080 total time=   1.2s
# [CV 4/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=None, n_estimators=100, subsample=0.1;, score=-0.074 total time=   1.0s
# [CV 5/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=None, n_estimators=100, subsample=0.1;, score=-0.080 total time=   1.1s
# [CV 5/5] END colsample_bytree=0.5, learning_rate=0.2, max_depth=10, n_estimators=300, subsample=0.3;, score=-0.053 total time=   7.2s
# [CV 1/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=5, n_estimators=200, subsample=0.5;, score=-0.077 total time=   1.6s
# [CV 2/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=5, n_estimators=200, subsample=0.5;, score=-0.080 total time=   1.6s
# [CV 3/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=5, n_estimators=200, subsample=0.5;, score=-0.077 total time=   1.6s
# [CV 4/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=5, n_estimators=200, subsample=0.5;, score=-0.073 total time=   1.5s
# [CV 5/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=5, n_estimators=200, subsample=0.5;, score=-0.077 total time=   1.6s
# [CV 1/5] END colsample_bytree=0.3, learning_rate=0.05, max_depth=5, n_estimators=600, subsample=0.9;, score=-0.054 total time=   3.5s
# [CV 2/5] END colsample_bytree=0.3, learning_rate=0.05, max_depth=5, n_estimators=600, subsample=0.9;, score=-0.057 total time=   3.6s
# [CV 3/5] END colsample_bytree=0.3, learning_rate=0.05, max_depth=5, n_estimators=600, subsample=0.9;, score=-0.054 total time=   3.5s
# [CV 4/5] END colsample_bytree=0.3, learning_rate=0.05, max_depth=5, n_estimators=600, subsample=0.9;, score=-0.049 total time=   3.5s
# [CV 5/5] END colsample_bytree=0.3, learning_rate=0.05, max_depth=5, n_estimators=600, subsample=0.9;, score=-0.055 total time=   3.2s
# [CV 2/5] END colsample_bytree=0.3, learning_rate=0.05, max_depth=50, n_estimators=100, subsample=0.7;, score=-0.049 total time= 3.7min
# [CV 3/5] END colsample_bytree=0.3, learning_rate=0.05, max_depth=50, n_estimators=100, subsample=0.7;, score=-0.047 total time= 3.8min
# [CV 1/5] END colsample_bytree=0.3, learning_rate=0.05, max_depth=50, n_estimators=100, subsample=0.7;, score=-0.050 total time= 3.8min
# [CV 5/5] END colsample_bytree=0.3, learning_rate=0.05, max_depth=50, n_estimators=100, subsample=0.7;, score=-0.051 total time= 4.0min
# [CV 4/5] END colsample_bytree=0.3, learning_rate=0.05, max_depth=50, n_estimators=100, subsample=0.7;, score=-0.043 total time= 4.4min
# [CV 1/5] END colsample_bytree=0.7, learning_rate=0.2, max_depth=100, n_estimators=200, subsample=0.5;, score=-0.051 total time= 3.5min
# [CV 2/5] END colsample_bytree=0.7, learning_rate=0.2, max_depth=100, n_estimators=200, subsample=0.5;, score=-0.051 total time= 4.1min
# [CV 4/5] END colsample_bytree=0.5, learning_rate=0.05, max_depth=50, n_estimators=200, subsample=1;, score=-0.038 total time= 6.6min
# [CV 3/5] END colsample_bytree=0.7, learning_rate=0.2, max_depth=100, n_estimators=200, subsample=0.5;, score=-0.051 total time= 3.9min
# [CV 1/5] END colsample_bytree=0.7, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.3;, score=-0.075 total time=   0.8s
# [CV 2/5] END colsample_bytree=0.7, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.3;, score=-0.078 total time=   0.9s
# [CV 3/5] END colsample_bytree=0.7, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.3;, score=-0.073 total time=   0.9s
# [CV 4/5] END colsample_bytree=0.7, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.3;, score=-0.070 total time=   1.0s
# [CV 5/5] END colsample_bytree=0.7, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.3;, score=-0.075 total time=   1.0s
# [CV 5/5] END colsample_bytree=0.7, learning_rate=0.2, max_depth=100, n_estimators=200, subsample=0.5;, score=-0.054 total time= 4.0min
# [CV 1/5] END colsample_bytree=0.5, learning_rate=0.1, max_depth=500, n_estimators=600, subsample=1;, score=-0.048 total time= 3.5min
# [CV 4/5] END colsample_bytree=0.7, learning_rate=0.2, max_depth=100, n_estimators=200, subsample=0.5;, score=-0.045 total time= 4.1min
# [CV 1/5] END colsample_bytree=0.7, learning_rate=0.2, max_depth=10, n_estimators=600, subsample=0.5;, score=-0.046 total time=  18.7s
# [CV 3/5] END colsample_bytree=0.5, learning_rate=0.05, max_depth=50, n_estimators=200, subsample=1;, score=-0.043 total time= 7.5min
# [CV 5/5] END colsample_bytree=0.5, learning_rate=0.05, max_depth=50, n_estimators=200, subsample=1;, score=-0.045 total time= 5.9min
# [CV 2/5] END colsample_bytree=0.7, learning_rate=0.2, max_depth=10, n_estimators=600, subsample=0.5;, score=-0.045 total time=  16.1s
# [CV 2/5] END colsample_bytree=0.5, learning_rate=0.1, max_depth=500, n_estimators=600, subsample=1;, score=-0.047 total time= 3.5min
# [CV 3/5] END colsample_bytree=0.7, learning_rate=0.2, max_depth=10, n_estimators=600, subsample=0.5;, score=-0.042 total time=  16.8s
# [CV 4/5] END colsample_bytree=0.7, learning_rate=0.2, max_depth=10, n_estimators=600, subsample=0.5;, score=-0.037 total time=  16.9s
# [CV 2/5] END colsample_bytree=0.5, learning_rate=0.05, max_depth=50, n_estimators=200, subsample=1;, score=-0.044 total time= 7.8min
# [CV 5/5] END colsample_bytree=0.7, learning_rate=0.2, max_depth=10, n_estimators=600, subsample=0.5;, score=-0.046 total time=  20.1s
# [CV 1/5] END colsample_bytree=0.5, learning_rate=0.05, max_depth=50, n_estimators=200, subsample=1;, score=-0.045 total time= 7.8min
# [CV 3/5] END colsample_bytree=0.5, learning_rate=0.1, max_depth=500, n_estimators=600, subsample=1;, score=-0.045 total time= 3.5min
# [CV 5/5] END colsample_bytree=0.5, learning_rate=0.2, max_depth=100, n_estimators=500, subsample=0.9;, score=-0.053 total time= 2.4min
# [CV 1/5] END colsample_bytree=0.5, learning_rate=0.2, max_depth=100, n_estimators=500, subsample=0.9;, score=-0.053 total time= 2.6min
# [CV 4/5] END colsample_bytree=0.5, learning_rate=0.1, max_depth=500, n_estimators=600, subsample=1;, score=-0.040 total time= 3.6min
# [CV 3/5] END colsample_bytree=0.5, learning_rate=0.2, max_depth=100, n_estimators=500, subsample=0.9;, score=-0.049 total time= 2.6min
# [CV 5/5] END colsample_bytree=0.5, learning_rate=0.1, max_depth=500, n_estimators=600, subsample=1;, score=-0.047 total time= 3.6min
# [CV 4/5] END colsample_bytree=0.5, learning_rate=0.2, max_depth=100, n_estimators=500, subsample=0.9;, score=-0.042 total time= 2.7min
# [CV 2/5] END colsample_bytree=0.5, learning_rate=0.2, max_depth=100, n_estimators=500, subsample=0.9;, score=-0.053 total time= 2.8min
# [CV 2/5] END colsample_bytree=0.5, learning_rate=0.1, max_depth=500, n_estimators=100, subsample=0.7;, score=-0.045 total time= 4.8min
# [CV 2/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=50, n_estimators=500, subsample=1;, score=-0.043 total time= 7.6min
# [CV 3/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=50, n_estimators=500, subsample=1;, score=-0.044 total time= 7.6min
# [CV 1/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=50, n_estimators=500, subsample=1;, score=-0.044 total time= 7.8min
# [CV 1/5] END colsample_bytree=0.5, learning_rate=0.05, max_depth=None, n_estimators=600, subsample=0.5;, score=-0.047 total time=   4.7s
# [CV 4/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=50, n_estimators=500, subsample=1;, score=-0.037 total time= 7.8min
# [CV 2/5] END colsample_bytree=0.5, learning_rate=0.05, max_depth=None, n_estimators=600, subsample=0.5;, score=-0.048 total time=   4.4s
# [CV 3/5] END colsample_bytree=0.5, learning_rate=0.05, max_depth=None, n_estimators=600, subsample=0.5;, score=-0.047 total time=   4.7s
# [CV 4/5] END colsample_bytree=0.5, learning_rate=0.05, max_depth=None, n_estimators=600, subsample=0.5;, score=-0.041 total time=   4.9s
# [CV 1/5] END colsample_bytree=0.5, learning_rate=0.1, max_depth=500, n_estimators=100, subsample=0.7;, score=-0.047 total time= 5.4min
# [CV 5/5] END colsample_bytree=0.5, learning_rate=0.05, max_depth=None, n_estimators=600, subsample=0.5;, score=-0.045 total time=   5.0s
# [CV 5/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=50, n_estimators=500, subsample=1;, score=-0.044 total time= 7.5min
# [CV 3/5] END colsample_bytree=0.5, learning_rate=0.2, max_depth=100, n_estimators=200, subsample=0.7;, score=-0.050 total time= 3.2min
# [CV 1/5] END colsample_bytree=0.5, learning_rate=0.2, max_depth=100, n_estimators=200, subsample=0.7;, score=-0.052 total time= 3.2min
# [CV 1/5] END colsample_bytree=0.5, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.9;, score=-0.067 total time=   1.1s
# [CV 2/5] END colsample_bytree=0.5, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.9;, score=-0.069 total time=   0.9s
# [CV 2/5] END colsample_bytree=0.5, learning_rate=0.2, max_depth=100, n_estimators=200, subsample=0.7;, score=-0.053 total time= 3.3min
# [CV 3/5] END colsample_bytree=0.5, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.9;, score=-0.065 total time=   0.9s
# [CV 4/5] END colsample_bytree=0.5, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.9;, score=-0.063 total time=   1.0s
# [CV 5/5] END colsample_bytree=0.5, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.9;, score=-0.067 total time=   0.9s
# [CV 4/5] END colsample_bytree=0.5, learning_rate=0.1, max_depth=500, n_estimators=100, subsample=0.7;, score=-0.039 total time= 4.6min
# [CV 5/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=500, n_estimators=300, subsample=0.7;, score=-0.043 total time= 9.8min
# [CV 4/5] END colsample_bytree=0.5, learning_rate=0.2, max_depth=100, n_estimators=200, subsample=0.7;, score=-0.044 total time= 3.2min
# [CV 3/5] END colsample_bytree=0.5, learning_rate=0.1, max_depth=500, n_estimators=100, subsample=0.7;, score=-0.044 total time= 4.9min
# [CV 1/5] END colsample_bytree=0.3, learning_rate=0.2, max_depth=5, n_estimators=300, subsample=1;, score=-0.050 total time=   2.3s
# [CV 5/5] END colsample_bytree=0.5, learning_rate=0.1, max_depth=500, n_estimators=100, subsample=0.7;, score=-0.047 total time= 4.7min
# [CV 2/5] END colsample_bytree=0.3, learning_rate=0.2, max_depth=5, n_estimators=300, subsample=1;, score=-0.053 total time=   2.3s
# [CV 4/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=500, n_estimators=300, subsample=0.7;, score=-0.035 total time= 9.9min
# [CV 3/5] END colsample_bytree=0.3, learning_rate=0.2, max_depth=5, n_estimators=300, subsample=1;, score=-0.050 total time=   2.4s
# python(42313) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(42314) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# [CV 4/5] END colsample_bytree=0.3, learning_rate=0.2, max_depth=5, n_estimators=300, subsample=1;, score=-0.046 total time=   2.2s
# [CV 5/5] END colsample_bytree=0.3, learning_rate=0.2, max_depth=5, n_estimators=300, subsample=1;, score=-0.051 total time=   2.3s
# [CV 2/5] END colsample_bytree=0.3, learning_rate=0.05, max_depth=500, n_estimators=600, subsample=0.1;, score=-0.047 total time= 1.3min
# [CV 1/5] END colsample_bytree=0.3, learning_rate=0.05, max_depth=500, n_estimators=600, subsample=0.1;, score=-0.046 total time= 1.3min
# [CV 3/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=500, n_estimators=300, subsample=0.7;, score=-0.041 total time=10.4min
# [CV 5/5] END colsample_bytree=0.5, learning_rate=0.2, max_depth=100, n_estimators=200, subsample=0.7;, score=-0.052 total time= 1.6min
# [CV 1/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=500, n_estimators=300, subsample=0.7;, score=-0.043 total time=10.5min
# [CV 2/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=500, n_estimators=300, subsample=0.7;, score=-0.042 total time=10.5min
# [CV 3/5] END colsample_bytree=0.3, learning_rate=0.05, max_depth=500, n_estimators=600, subsample=0.1;, score=-0.043 total time= 1.3min
# [CV 4/5] END colsample_bytree=0.3, learning_rate=0.05, max_depth=500, n_estimators=600, subsample=0.1;, score=-0.039 total time= 1.3min
# [CV 5/5] END colsample_bytree=0.3, learning_rate=0.05, max_depth=500, n_estimators=600, subsample=0.1;, score=-0.045 total time= 1.3min
# [CV 2/5] END colsample_bytree=0.3, learning_rate=0.2, max_depth=10, n_estimators=400, subsample=0.9;, score=-0.046 total time=   9.1s
# [CV 1/5] END colsample_bytree=0.3, learning_rate=0.2, max_depth=10, n_estimators=400, subsample=0.9;, score=-0.046 total time=   9.8s
# [CV 3/5] END colsample_bytree=0.3, learning_rate=0.2, max_depth=10, n_estimators=400, subsample=0.9;, score=-0.042 total time=   8.7s
# [CV 4/5] END colsample_bytree=0.3, learning_rate=0.2, max_depth=10, n_estimators=400, subsample=0.9;, score=-0.036 total time=   8.8s
# [CV 1/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=10, n_estimators=200, subsample=0.1;, score=-0.056 total time=   4.2s
# [CV 2/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=10, n_estimators=200, subsample=0.1;, score=-0.058 total time=   4.4s
# [CV 5/5] END colsample_bytree=0.3, learning_rate=0.2, max_depth=10, n_estimators=400, subsample=0.9;, score=-0.046 total time=   9.3s
# [CV 3/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=10, n_estimators=200, subsample=0.1;, score=-0.055 total time=   4.2s
# [CV 4/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=10, n_estimators=200, subsample=0.1;, score=-0.049 total time=   4.4s
# [CV 5/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=10, n_estimators=200, subsample=0.1;, score=-0.055 total time=   4.4s
# [CV 1/5] END colsample_bytree=0.7, learning_rate=0.2, max_depth=500, n_estimators=400, subsample=1;, score=-0.050 total time= 1.9min
# [CV 2/5] END colsample_bytree=0.7, learning_rate=0.2, max_depth=500, n_estimators=400, subsample=1;, score=-0.050 total time= 1.9min
# [CV 4/5] END colsample_bytree=0.3, learning_rate=0.2, max_depth=100, n_estimators=600, subsample=0.7;, score=-0.050 total time= 3.8min
# [CV 2/5] END colsample_bytree=0.3, learning_rate=0.2, max_depth=100, n_estimators=600, subsample=0.7;, score=-0.058 total time= 4.0min
# [CV 3/5] END colsample_bytree=0.3, learning_rate=0.2, max_depth=100, n_estimators=600, subsample=0.7;, score=-0.054 total time= 4.0min
# [CV 1/5] END colsample_bytree=0.3, learning_rate=0.2, max_depth=100, n_estimators=600, subsample=0.7;, score=-0.056 total time= 4.0min
# [CV 1/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=400, subsample=0.3;, score=-0.041 total time=  10.7s
# [CV 2/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=400, subsample=0.3;, score=-0.043 total time=   9.4s
# [CV 3/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=400, subsample=0.3;, score=-0.041 total time=  10.1s
# [CV 5/5] END colsample_bytree=0.3, learning_rate=0.2, max_depth=100, n_estimators=600, subsample=0.7;, score=-0.058 total time= 3.5min
# [CV 4/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=400, subsample=0.3;, score=-0.035 total time=  10.8s
# [CV 5/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=400, subsample=0.3;, score=-0.041 total time=  12.3s
# [CV 1/5] END colsample_bytree=0.5, learning_rate=0.2, max_depth=10, n_estimators=400, subsample=0.7;, score=-0.043 total time=  12.3s
# [CV 2/5] END colsample_bytree=0.5, learning_rate=0.2, max_depth=10, n_estimators=400, subsample=0.7;, score=-0.044 total time=  10.8s
# [CV 1/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.3;, score=-0.081 total time=   1.2s
# [CV 2/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.3;, score=-0.083 total time=   1.0s
# [CV 3/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.3;, score=-0.082 total time=   1.3s
# [CV 3/5] END colsample_bytree=0.5, learning_rate=0.2, max_depth=10, n_estimators=400, subsample=0.7;, score=-0.043 total time=  11.1s
# [CV 4/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.3;, score=-0.078 total time=   1.0s
# [CV 5/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.3;, score=-0.082 total time=   1.0s
# [CV 4/5] END colsample_bytree=0.5, learning_rate=0.2, max_depth=10, n_estimators=400, subsample=0.7;, score=-0.039 total time=  11.2s
# [CV 1/5] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=400, subsample=1;, score=-0.061 total time=   2.9s
# [CV 2/5] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=400, subsample=1;, score=-0.063 total time=   3.0s
# [CV 3/5] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=400, subsample=1;, score=-0.060 total time=   3.1s
# [CV 5/5] END colsample_bytree=0.5, learning_rate=0.2, max_depth=10, n_estimators=400, subsample=0.7;, score=-0.045 total time=  12.9s
# [CV 4/5] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=400, subsample=1;, score=-0.056 total time=   3.0s
# [CV 5/5] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=400, subsample=1;, score=-0.062 total time=   2.9s
# [CV 3/5] END colsample_bytree=0.7, learning_rate=0.2, max_depth=500, n_estimators=400, subsample=1;, score=-0.051 total time= 1.8min
# [CV 4/5] END colsample_bytree=0.7, learning_rate=0.2, max_depth=500, n_estimators=400, subsample=1;, score=-0.043 total time= 1.8min
# [CV 1/5] END colsample_bytree=0.3, learning_rate=0.2, max_depth=50, n_estimators=300, subsample=0.1;, score=-0.124 total time=  41.8s
# [CV 2/5] END colsample_bytree=0.3, learning_rate=0.2, max_depth=50, n_estimators=300, subsample=0.1;, score=-0.129 total time=  41.7s
# [CV 3/5] END colsample_bytree=0.3, learning_rate=0.2, max_depth=50, n_estimators=300, subsample=0.1;, score=-0.122 total time=  42.2s
# [CV 4/5] END colsample_bytree=0.3, learning_rate=0.2, max_depth=50, n_estimators=300, subsample=0.1;, score=-0.116 total time=  42.4s
# [CV 1/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=500, n_estimators=300, subsample=0.7;, score=-0.052 total time= 5.7min
# [CV 5/5] END colsample_bytree=0.7, learning_rate=0.2, max_depth=500, n_estimators=400, subsample=1;, score=-0.049 total time= 1.5min
# [CV 2/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=500, n_estimators=300, subsample=0.7;, score=-0.049 total time= 5.9min
# [CV 3/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=500, n_estimators=300, subsample=0.7;, score=-0.048 total time= 5.9min
# [CV 5/5] END colsample_bytree=0.3, learning_rate=0.2, max_depth=50, n_estimators=300, subsample=0.1;, score=-0.125 total time=  43.3s
# [CV 4/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=500, n_estimators=300, subsample=0.7;, score=-0.042 total time= 5.9min
# [CV 5/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=500, n_estimators=300, subsample=0.7;, score=-0.051 total time= 6.5min
# [CV 4/5] END colsample_bytree=0.5, learning_rate=0.1, max_depth=50, n_estimators=600, subsample=0.9;, score=-0.038 total time= 4.5min
# [CV 3/5] END colsample_bytree=0.5, learning_rate=0.1, max_depth=50, n_estimators=600, subsample=0.9;, score=-0.045 total time= 4.6min
# [CV 5/5] END colsample_bytree=0.5, learning_rate=0.1, max_depth=50, n_estimators=600, subsample=0.9;, score=-0.047 total time= 4.6min
# [CV 2/5] END colsample_bytree=0.5, learning_rate=0.1, max_depth=50, n_estimators=600, subsample=0.9;, score=-0.046 total time= 4.9min
# [CV 1/5] END colsample_bytree=0.5, learning_rate=0.1, max_depth=50, n_estimators=600, subsample=0.9;, score=-0.046 total time= 5.3min
# [CV 1/5] END colsample_bytree=0.5, learning_rate=0.1, max_depth=50, n_estimators=300, subsample=0.7;, score=-0.047 total time= 5.3min
# [CV 2/5] END colsample_bytree=0.5, learning_rate=0.1, max_depth=50, n_estimators=300, subsample=0.7;, score=-0.045 total time= 5.5min
# [CV 1/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=50, n_estimators=400, subsample=0.5;, score=-0.051 total time= 7.1min
# [CV 4/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=50, n_estimators=400, subsample=0.5;, score=-0.042 total time= 7.0min
# [CV 5/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=50, n_estimators=400, subsample=0.5;, score=-0.051 total time= 7.6min
# [CV 2/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=50, n_estimators=400, subsample=0.5;, score=-0.050 total time= 8.1min
# [CV 3/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=50, n_estimators=400, subsample=0.5;, score=-0.047 total time= 8.3min
# [CV 1/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=50, n_estimators=200, subsample=0.9;, score=-0.045 total time= 4.4min
# [CV 2/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=50, n_estimators=200, subsample=0.9;, score=-0.044 total time= 4.4min
# [CV 1/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=200, subsample=0.5;, score=-0.042 total time=   6.1s
# [CV 2/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=200, subsample=0.5;, score=-0.042 total time=   6.0s
# [CV 3/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=200, subsample=0.5;, score=-0.041 total time=   5.9s
# [CV 4/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=200, subsample=0.5;, score=-0.034 total time=   6.1s
# [CV 3/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=50, n_estimators=200, subsample=0.9;, score=-0.046 total time= 4.5min
# [CV 5/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=200, subsample=0.5;, score=-0.041 total time=   6.9s
# ...
# [CV 5/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=None, n_estimators=400, subsample=1;, score=-0.045 total time=   3.4s
# [CV 4/5] END colsample_bytree=0.5, learning_rate=0.1, max_depth=500, n_estimators=500, subsample=0.1;, score=-0.048 total time= 1.3min
# [CV 1/5] END colsample_bytree=0.5, learning_rate=0.2, max_depth=None, n_estimators=100, subsample=0.9;, score=-0.056 total time=   1.2s
# python(42440) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# [CV 2/5] END colsample_bytree=0.5, learning_rate=0.2, max_depth=None, n_estimators=100, subsample=0.9;, score=-0.060 total time=   1.2s
# [CV 3/5] END colsample_bytree=0.5, learning_rate=0.2, max_depth=None, n_estimators=100, subsample=0.9;, score=-0.056 total time=   1.3s
# [CV 4/5] END colsample_bytree=0.5, learning_rate=0.2, max_depth=None, n_estimators=100, subsample=0.9;, score=-0.052 total time=   1.2s
# [CV 2/5] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=0.5;, score=-0.038 total time=  14.0s
# [CV 5/5] END colsample_bytree=0.5, learning_rate=0.2, max_depth=None, n_estimators=100, subsample=0.9;, score=-0.056 total time=   1.2s
# python(42442) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# [CV 1/5] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=0.5;, score=-0.038 total time=  15.7s
# [CV 3/5] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=0.5;, score=-0.037 total time=  14.7s
# [CV 4/5] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=0.5;, score=-0.031 total time=  15.3s
# [CV 5/5] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=0.5;, score=-0.038 total time=  16.6s
# [CV 1/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=100, n_estimators=600, subsample=0.7;, score=-0.043 total time= 8.4min
# [CV 2/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=100, n_estimators=600, subsample=0.7;, score=-0.042 total time= 7.9min
# [CV 3/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=100, n_estimators=600, subsample=0.7;, score=-0.041 total time= 7.6min
# [CV 5/5] END colsample_bytree=0.5, learning_rate=0.1, max_depth=500, n_estimators=500, subsample=0.1;, score=-0.055 total time= 1.3min
# [CV 1/5] END colsample_bytree=0.3, learning_rate=0.2, max_depth=500, n_estimators=400, subsample=0.1;, score=-0.132 total time=  57.8s
# [CV 4/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=100, n_estimators=600, subsample=0.7;, score=-0.035 total time= 7.6min
# [CV 5/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=100, n_estimators=600, subsample=0.7;, score=-0.043 total time= 6.9min
# [CV 2/5] END colsample_bytree=0.3, learning_rate=0.2, max_depth=500, n_estimators=400, subsample=0.1;, score=-0.132 total time=  56.5s
# [CV 3/5] END colsample_bytree=0.3, learning_rate=0.2, max_depth=500, n_estimators=400, subsample=0.1;, score=-0.126 total time=  56.4s
# [CV 4/5] END colsample_bytree=0.3, learning_rate=0.2, max_depth=500, n_estimators=400, subsample=0.1;, score=-0.116 total time=  56.6s
# [CV 5/5] END colsample_bytree=0.3, learning_rate=0.2, max_depth=500, n_estimators=400, subsample=0.1;, score=-0.133 total time=  55.8s
# [CV 2/5] END colsample_bytree=0.5, learning_rate=0.2, max_depth=100, n_estimators=300, subsample=0.1;, score=-0.110 total time=  47.6s
# [CV 1/5] END colsample_bytree=0.5, learning_rate=0.2, max_depth=100, n_estimators=300, subsample=0.1;, score=-0.114 total time=  48.4s
# [CV 3/5] END colsample_bytree=0.5, learning_rate=0.2, max_depth=100, n_estimators=300, subsample=0.1;, score=-0.108 total time=  47.5s
# [CV 4/5] END colsample_bytree=0.5, learning_rate=0.2, max_depth=100, n_estimators=300, subsample=0.1;, score=-0.109 total time=  46.3s
# [CV 5/5] END colsample_bytree=0.5, learning_rate=0.2, max_depth=100, n_estimators=300, subsample=0.1;, score=-0.112 total time=  45.2s
# [CV 1/5] END colsample_bytree=0.5, learning_rate=0.1, max_depth=100, n_estimators=100, subsample=1;, score=-0.048 total time= 3.8min
# [CV 2/5] END colsample_bytree=0.5, learning_rate=0.1, max_depth=100, n_estimators=100, subsample=1;, score=-0.047 total time= 3.8min
# [CV 5/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=500, n_estimators=200, subsample=0.9;, score=-0.044 total time= 7.4min
# [CV 3/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=500, n_estimators=200, subsample=0.9;, score=-0.043 total time= 8.0min
# [CV 1/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=500, n_estimators=200, subsample=0.9;, score=-0.043 total time= 8.3min
# [CV 4/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=500, n_estimators=200, subsample=0.9;, score=-0.036 total time= 8.4min
# [CV 2/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=500, n_estimators=200, subsample=0.9;, score=-0.042 total time= 8.4min
# [CV 3/5] END colsample_bytree=0.5, learning_rate=0.1, max_depth=100, n_estimators=100, subsample=1;, score=-0.045 total time= 3.7min
# [CV 4/5] END colsample_bytree=0.5, learning_rate=0.1, max_depth=100, n_estimators=100, subsample=1;, score=-0.040 total time= 4.2min
# [CV 1/5] END colsample_bytree=0.5, learning_rate=0.1, max_depth=10, n_estimators=500, subsample=0.5;, score=-0.039 total time=  12.4s
# [CV 2/5] END colsample_bytree=0.5, learning_rate=0.1, max_depth=10, n_estimators=500, subsample=0.5;, score=-0.040 total time=  11.4s
# [CV 3/5] END colsample_bytree=0.5, learning_rate=0.1, max_depth=10, n_estimators=500, subsample=0.5;, score=-0.038 total time=  12.8s
# [CV 4/5] END colsample_bytree=0.5, learning_rate=0.1, max_depth=10, n_estimators=500, subsample=0.5;, score=-0.033 total time=  13.5s
# [CV 5/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=50, n_estimators=500, subsample=0.5;, score=-0.051 total time= 1.5min
# [CV 5/5] END colsample_bytree=0.5, learning_rate=0.1, max_depth=10, n_estimators=500, subsample=0.5;, score=-0.040 total time=  14.6s
# [CV 1/5] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=400, subsample=0.7;, score=-0.062 total time=   3.0s
# [CV 2/5] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=400, subsample=0.7;, score=-0.063 total time=   2.6s
# [CV 3/5] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=400, subsample=0.7;, score=-0.060 total time=   2.5s
# [CV 4/5] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=400, subsample=0.7;, score=-0.056 total time=   2.7s
# [CV 5/5] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=400, subsample=0.7;, score=-0.061 total time=   2.8s
# [CV 5/5] END colsample_bytree=0.5, learning_rate=0.1, max_depth=100, n_estimators=100, subsample=1;, score=-0.047 total time= 4.1min
# [CV 5/5] END colsample_bytree=0.5, learning_rate=0.05, max_depth=500, n_estimators=300, subsample=0.7;, score=-0.044 total time=10.2min
# [CV 4/5] END colsample_bytree=0.5, learning_rate=0.05, max_depth=500, n_estimators=300, subsample=0.7;, score=-0.036 total time=11.2min
# [CV 3/5] END colsample_bytree=0.5, learning_rate=0.05, max_depth=500, n_estimators=300, subsample=0.7;, score=-0.042 total time=11.3min
# [CV 1/5] END colsample_bytree=0.5, learning_rate=0.05, max_depth=500, n_estimators=300, subsample=0.7;, score=-0.043 total time=11.6min
# [CV 2/5] END colsample_bytree=0.5, learning_rate=0.05, max_depth=500, n_estimators=300, subsample=0.7;, score=-0.043 total time=11.6min
# [CV 1/5] END colsample_bytree=0.3, learning_rate=0.2, max_depth=500, n_estimators=400, subsample=0.3;, score=-0.062 total time= 1.3min
# [CV 3/5] END colsample_bytree=0.3, learning_rate=0.2, max_depth=500, n_estimators=400, subsample=0.3;, score=-0.062 total time= 1.4min
# [CV 2/5] END colsample_bytree=0.3, learning_rate=0.2, max_depth=500, n_estimators=400, subsample=0.3;, score=-0.061 total time= 1.4min
# [CV 1/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=50, n_estimators=500, subsample=0.5;, score=-0.051 total time= 6.9min
# [CV 1/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=10, n_estimators=400, subsample=0.7;, score=-0.038 total time=  14.0s
# [CV 2/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=10, n_estimators=400, subsample=0.7;, score=-0.038 total time=  13.8s
# [CV 3/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=10, n_estimators=400, subsample=0.7;, score=-0.038 total time=  14.8s
# [CV 2/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=50, n_estimators=500, subsample=0.5;, score=-0.050 total time= 7.1min
# [CV 4/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=10, n_estimators=400, subsample=0.7;, score=-0.031 total time=  15.2s
# [CV 5/5] END colsample_bytree=0.7, learning_rate=0.05, max_depth=10, n_estimators=400, subsample=0.7;, score=-0.038 total time=  16.7s
# [CV 3/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=50, n_estimators=500, subsample=0.5;, score=-0.047 total time= 7.2min
# [CV 4/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=50, n_estimators=500, subsample=0.5;, score=-0.042 total time= 7.3min
# [CV 4/5] END colsample_bytree=0.3, learning_rate=0.2, max_depth=500, n_estimators=400, subsample=0.3;, score=-0.058 total time= 1.6min
# [CV 5/5] END colsample_bytree=0.3, learning_rate=0.2, max_depth=500, n_estimators=400, subsample=0.3;, score=-0.064 total time= 1.6min
# [CV 1/5] END colsample_bytree=0.5, learning_rate=0.1, max_depth=10, n_estimators=500, subsample=0.9;, score=-0.038 total time=  16.2s
# [CV 2/5] END colsample_bytree=0.5, learning_rate=0.1, max_depth=10, n_estimators=500, subsample=0.9;, score=-0.038 total time=  15.1s
# [CV 3/5] END colsample_bytree=0.5, learning_rate=0.1, max_depth=10, n_estimators=500, subsample=0.9;, score=-0.037 total time=  15.4s
# [CV 4/5] END colsample_bytree=0.5, learning_rate=0.1, max_depth=10, n_estimators=500, subsample=0.9;, score=-0.032 total time=  16.1s
# [CV 5/5] END colsample_bytree=0.5, learning_rate=0.1, max_depth=10, n_estimators=500, subsample=0.9;, score=-0.040 total time=  17.9s
# [CV 1/5] END colsample_bytree=0.3, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=1;, score=-0.058 total time=   3.6s
# [CV 2/5] END colsample_bytree=0.3, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=1;, score=-0.060 total time=   3.5s
# [CV 3/5] END colsample_bytree=0.3, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=1;, score=-0.057 total time=   3.6s
# [CV 4/5] END colsample_bytree=0.3, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=1;, score=-0.052 total time=   3.7s
# [CV 5/5] END colsample_bytree=0.3, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=1;, score=-0.059 total time=   3.5s
# [CV 1/5] END colsample_bytree=0.5, learning_rate=0.1, max_depth=50, n_estimators=500, subsample=0.3;, score=-0.046 total time= 2.5min
# [CV 2/5] END colsample_bytree=0.5, learning_rate=0.1, max_depth=50, n_estimators=500, subsample=0.3;, score=-0.046 total time= 2.5min
# [CV 3/5] END colsample_bytree=0.5, learning_rate=0.1, max_depth=50, n_estimators=500, subsample=0.3;, score=-0.043 total time= 2.4min
# [CV 4/5] END colsample_bytree=0.5, learning_rate=0.1, max_depth=50, n_estimators=500, subsample=0.3;, score=-0.039 total time= 2.5min
# [CV 1/5] END colsample_bytree=0.7, learning_rate=0.2, max_depth=5, n_estimators=600, subsample=1;, score=-0.041 total time=   3.6s
# [CV 5/5] END colsample_bytree=0.5, learning_rate=0.1, max_depth=50, n_estimators=500, subsample=0.3;, score=-0.046 total time= 2.4min
# [CV 2/5] END colsample_bytree=0.7, learning_rate=0.2, max_depth=5, n_estimators=600, subsample=1;, score=-0.044 total time=   3.7s
# [CV 3/5] END colsample_bytree=0.7, learning_rate=0.2, max_depth=5, n_estimators=600, subsample=1;, score=-0.041 total time=   3.9s
# [CV 4/5] END colsample_bytree=0.7, learning_rate=0.2, max_depth=5, n_estimators=600, subsample=1;, score=-0.038 total time=   3.7s
# [CV 5/5] END colsample_bytree=0.7, learning_rate=0.2, max_depth=5, n_estimators=600, subsample=1;, score=-0.044 total time=   3.7s
# [CV 2/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=600, subsample=0.3;, score=-0.042 total time=  13.4s
# [CV 1/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=600, subsample=0.3;, score=-0.040 total time=  16.0s
# [CV 3/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=600, subsample=0.3;, score=-0.040 total time=  14.6s
# [CV 4/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=600, subsample=0.3;, score=-0.034 total time=  15.2s
# [CV 5/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=600, subsample=0.3;, score=-0.040 total time=  17.8s
# [CV 1/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=500, n_estimators=500, subsample=0.1;, score=-0.055 total time= 1.3min
# [CV 2/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=500, n_estimators=500, subsample=0.1;, score=-0.055 total time= 1.3min
# [CV 1/5] END colsample_bytree=0.5, learning_rate=0.05, max_depth=100, n_estimators=300, subsample=0.7;, score=-0.043 total time= 9.4min
# [CV 2/5] END colsample_bytree=0.5, learning_rate=0.1, max_depth=50, n_estimators=500, subsample=1;, score=-0.047 total time= 3.9min
# [CV 1/5] END colsample_bytree=0.3, learning_rate=0.05, max_depth=None, n_estimators=500, subsample=1;, score=-0.048 total time=   4.3s
# [CV 2/5] END colsample_bytree=0.3, learning_rate=0.05, max_depth=None, n_estimators=500, subsample=1;, score=-0.049 total time=   4.6s
# [CV 3/5] END colsample_bytree=0.3, learning_rate=0.05, max_depth=None, n_estimators=500, subsample=1;, score=-0.047 total time=   4.7s
# [CV 1/5] END colsample_bytree=0.5, learning_rate=0.1, max_depth=50, n_estimators=500, subsample=1;, score=-0.048 total time= 4.1min
# python(42637) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# [CV 4/5] END colsample_bytree=0.3, learning_rate=0.05, max_depth=None, n_estimators=500, subsample=1;, score=-0.043 total time=   4.6s
# [CV 3/5] END colsample_bytree=0.5, learning_rate=0.1, max_depth=50, n_estimators=500, subsample=1;, score=-0.045 total time= 3.4min
# [CV 5/5] END colsample_bytree=0.5, learning_rate=0.1, max_depth=50, n_estimators=500, subsample=1;, score=-0.047 total time= 3.3min
# [CV 5/5] END colsample_bytree=0.3, learning_rate=0.05, max_depth=None, n_estimators=500, subsample=1;, score=-0.048 total time=   3.9s
# [CV 4/5] END colsample_bytree=0.5, learning_rate=0.1, max_depth=50, n_estimators=500, subsample=1;, score=-0.040 total time= 3.4min
# [CV 4/5] END colsample_bytree=0.5, learning_rate=0.05, max_depth=100, n_estimators=300, subsample=0.7;, score=-0.036 total time= 8.9min
# [CV 3/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=500, n_estimators=500, subsample=0.1;, score=-0.053 total time= 1.3min
# [CV 3/5] END colsample_bytree=0.5, learning_rate=0.05, max_depth=100, n_estimators=300, subsample=0.7;, score=-0.042 total time= 9.9min
# [CV 2/5] END colsample_bytree=0.5, learning_rate=0.05, max_depth=100, n_estimators=300, subsample=0.7;, score=-0.043 total time= 9.9min
# [CV 4/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=500, n_estimators=500, subsample=0.1;, score=-0.047 total time= 1.2min
# [CV 5/5] END colsample_bytree=0.5, learning_rate=0.05, max_depth=100, n_estimators=300, subsample=0.7;, score=-0.044 total time= 8.5min
# [CV 5/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=500, n_estimators=500, subsample=0.1;, score=-0.054 total time=  54.7s
# Best: -0.035551 using {'subsample': 0.9, 'n_estimators': 600, 'max_depth': 10, 'learning_rate': 0.05, 'colsample_bytree': 0.7}
# MAE: 0.08885524096757207
# RMSE: 0.182205315107911
# R2: 0.971408265081906
# /Users/sara/.pyenv/versions/3.10.0/envs/yao_project/lib/python3.10/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
best_xgb
# save the model
import joblib
joblib.dump(best_xgb, 'xgb_formation_energy_model.pkl')
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.7, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.05, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=10, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=600, n_jobs=-1,
#              num_parallel_tree=None, random_state=42, ...)

# %% [markdown]
# # KNN

# %%
# pick up from here next time

from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import pandas as pd

# Define the parameter grid for KNN
param_grid = {
    'regressor__n_neighbors': [3, 5, 7, 9],
    'regressor__weights': ['uniform', 'distance'],
    'regressor__algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
    'regressor__leaf_size': [20, 30, 40, 50],
    'regressor__p': [1, 2]  # for different distance metrics: Manhattan and Euclidean
}


# Define the model
#knn = KNeighborsRegressor(n_jobs=-1)
pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('regressor', KNeighborsRegressor(n_jobs=-1))
])

# Define the search, using 5-fold cross-validation within the training set
search = GridSearchCV(
    pipeline,
    param_grid,
    scoring='neg_mean_squared_error',
    n_jobs=-1,
    cv=5,
    verbose=3
)

# Perform the search
search.fit(X_train, y_train)

# Save the results of the search to CSV
results = pd.DataFrame(search.cv_results_)
results.to_csv('knn_hyperparameter_tuning.csv')

# Summarize the best score and configuration
print("Best: %f using %s" % (search.best_score_, search.best_params_))

# Train the model with the best hyperparameters
best_knn = search.best_estimator_
best_knn.fit(X_train, y_train)

# Evaluate the model using MAE, RMSE, and R2
y_pred_knn = best_knn.predict(X_test)
print('MAE:', mean_absolute_error(y_test, y_pred_knn))
print('RMSE:', mean_squared_error(y_test, y_pred_knn, squared=False))
print('R2:', r2_score(y_test, y_pred_knn))

df_y_knn = pd.DataFrame({'y_test': y_test, 'y_pred_knn': y_pred_knn})
df_y_knn.to_csv('knn_y_test_y_pred.csv')
# Out:
# Fitting 5 folds for each of 256 candidates, totalling 1280 fits
# python(42917) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(42918) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(42919) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(42920) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(42921) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(42922) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(42923) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(42924) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(42925) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(42926) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(42927) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(42928) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# [CV 1/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=3, regressor__p=2, regressor__weights=uniform;, score=-0.082 total time=   2.9s
# [CV 2/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=3, regressor__p=2, regressor__weights=uniform;, score=-0.082 total time=   3.0s
# [CV 4/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=3, regressor__p=2, regressor__weights=uniform;, score=-0.074 total time=   2.8s
# [CV 3/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=3, regressor__p=2, regressor__weights=uniform;, score=-0.077 total time=   2.9s
# [CV 1/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=3, regressor__p=2, regressor__weights=distance;, score=-0.075 total time=   2.8s
# [CV 5/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=3, regressor__p=2, regressor__weights=uniform;, score=-0.090 total time=   3.0s
# [CV 2/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=3, regressor__p=2, regressor__weights=distance;, score=-0.075 total time=   3.0s
# [CV 3/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=3, regressor__p=2, regressor__weights=distance;, score=-0.071 total time=   2.9s
# [CV 4/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=3, regressor__p=1, regressor__weights=uniform;, score=-0.062 total time=  13.2s
# [CV 2/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=3, regressor__p=1, regressor__weights=uniform;, score=-0.070 total time=  13.3s
# [CV 1/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=3, regressor__p=1, regressor__weights=uniform;, score=-0.069 total time=  13.4s
# [CV 1/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=3, regressor__p=1, regressor__weights=distance;, score=-0.064 total time=  13.2s
# [CV 4/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=3, regressor__p=1, regressor__weights=distance;, score=-0.056 total time=  13.2s
# [CV 3/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=3, regressor__p=1, regressor__weights=uniform;, score=-0.067 total time=  13.6s
# [CV 5/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=3, regressor__p=1, regressor__weights=uniform;, score=-0.076 total time=  13.5s
# [CV 2/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=3, regressor__p=1, regressor__weights=distance;, score=-0.064 total time=  13.5s
# [CV 5/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=3, regressor__p=1, regressor__weights=distance;, score=-0.072 total time=  13.5s
# [CV 3/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=3, regressor__p=1, regressor__weights=distance;, score=-0.061 total time=  13.7s
# [CV 4/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=3, regressor__p=2, regressor__weights=distance;, score=-0.067 total time=   3.0s
# [CV 5/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=3, regressor__p=2, regressor__weights=distance;, score=-0.085 total time=   2.9s
# [CV 2/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=5, regressor__p=2, regressor__weights=uniform;, score=-0.087 total time=   3.1s
# [CV 1/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=5, regressor__p=2, regressor__weights=uniform;, score=-0.085 total time=   3.1s
# [CV 3/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=5, regressor__p=2, regressor__weights=uniform;, score=-0.082 total time=   2.9s
# [CV 4/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=5, regressor__p=2, regressor__weights=uniform;, score=-0.079 total time=   3.0s
# [CV 5/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=5, regressor__p=2, regressor__weights=uniform;, score=-0.092 total time=   2.9s
# [CV 1/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=5, regressor__p=2, regressor__weights=distance;, score=-0.075 total time=   2.9s
# [CV 1/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=5, regressor__p=1, regressor__weights=uniform;, score=-0.074 total time=  13.3s
# [CV 3/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=5, regressor__p=1, regressor__weights=uniform;, score=-0.068 total time=  13.3s
# [CV 2/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=5, regressor__p=1, regressor__weights=uniform;, score=-0.075 total time=  13.4s
# [CV 4/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=5, regressor__p=1, regressor__weights=uniform;, score=-0.066 total time=  13.3s
# [CV 2/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=5, regressor__p=2, regressor__weights=distance;, score=-0.075 total time=   2.8s
# [CV 1/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=5, regressor__p=1, regressor__weights=distance;, score=-0.065 total time=  13.2s
# [CV 3/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=5, regressor__p=1, regressor__weights=distance;, score=-0.060 total time=  13.3s
# [CV 5/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=5, regressor__p=1, regressor__weights=uniform;, score=-0.077 total time=  13.4s
# [CV 3/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=5, regressor__p=2, regressor__weights=distance;, score=-0.073 total time=   2.9s
# [CV 2/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=5, regressor__p=1, regressor__weights=distance;, score=-0.064 total time=  13.6s
# [CV 4/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=5, regressor__p=1, regressor__weights=distance;, score=-0.056 total time=  13.6s
# [CV 5/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=5, regressor__p=1, regressor__weights=distance;, score=-0.071 total time=  13.6s
# [CV 4/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=5, regressor__p=2, regressor__weights=distance;, score=-0.068 total time=   2.9s
# [CV 5/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=5, regressor__p=2, regressor__weights=distance;, score=-0.084 total time=   2.8s
# [CV 1/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=7, regressor__p=2, regressor__weights=uniform;, score=-0.089 total time=   2.8s
# [CV 2/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=7, regressor__p=2, regressor__weights=uniform;, score=-0.094 total time=   2.9s
# [CV 4/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=7, regressor__p=2, regressor__weights=uniform;, score=-0.084 total time=   2.8s
# [CV 3/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=7, regressor__p=2, regressor__weights=uniform;, score=-0.085 total time=   3.0s
# [CV 5/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=7, regressor__p=2, regressor__weights=uniform;, score=-0.095 total time=   2.8s
# [CV 1/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=7, regressor__p=2, regressor__weights=distance;, score=-0.077 total time=   2.9s
# [CV 3/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=7, regressor__p=1, regressor__weights=uniform;, score=-0.072 total time=  13.2s
# [CV 1/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=7, regressor__p=1, regressor__weights=distance;, score=-0.066 total time=  13.1s
# [CV 2/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=7, regressor__p=1, regressor__weights=uniform;, score=-0.079 total time=  13.4s
# [CV 1/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=7, regressor__p=1, regressor__weights=uniform;, score=-0.077 total time=  13.4s
# [CV 5/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=7, regressor__p=1, regressor__weights=uniform;, score=-0.079 total time=  13.2s
# [CV 4/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=7, regressor__p=1, regressor__weights=uniform;, score=-0.070 total time=  13.4s
# [CV 2/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=7, regressor__p=1, regressor__weights=distance;, score=-0.065 total time=  13.2s
# [CV 3/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=7, regressor__p=1, regressor__weights=distance;, score=-0.062 total time=  13.2s
# [CV 5/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=7, regressor__p=1, regressor__weights=distance;, score=-0.071 total time=  13.2s
# [CV 4/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=7, regressor__p=1, regressor__weights=distance;, score=-0.058 total time=  13.4s
# [CV 3/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=7, regressor__p=2, regressor__weights=distance;, score=-0.074 total time=   2.9s
# [CV 2/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=7, regressor__p=2, regressor__weights=distance;, score=-0.079 total time=   3.0s
# [CV 4/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=7, regressor__p=2, regressor__weights=distance;, score=-0.071 total time=   2.9s
# [CV 5/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=7, regressor__p=2, regressor__weights=distance;, score=-0.085 total time=   3.0s
# [CV 1/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=9, regressor__p=2, regressor__weights=uniform;, score=-0.093 total time=   3.0s
# [CV 2/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=9, regressor__p=2, regressor__weights=uniform;, score=-0.100 total time=   3.1s
# [CV 3/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=9, regressor__p=2, regressor__weights=uniform;, score=-0.089 total time=   2.9s
# [CV 4/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=9, regressor__p=2, regressor__weights=uniform;, score=-0.090 total time=   3.0s
# [CV 5/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=9, regressor__p=2, regressor__weights=uniform;, score=-0.098 total time=   3.1s
# [CV 1/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=9, regressor__p=2, regressor__weights=distance;, score=-0.080 total time=   3.2s
# [CV 5/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=9, regressor__p=1, regressor__weights=uniform;, score=-0.081 total time=  13.3s
# [CV 1/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=9, regressor__p=1, regressor__weights=uniform;, score=-0.080 total time=  13.5s
# [CV 2/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=9, regressor__p=1, regressor__weights=uniform;, score=-0.082 total time=  13.5s
# [CV 4/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=9, regressor__p=1, regressor__weights=uniform;, score=-0.074 total time=  13.7s
# [CV 3/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=9, regressor__p=1, regressor__weights=uniform;, score=-0.075 total time=  13.8s
# [CV 1/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=9, regressor__p=1, regressor__weights=distance;, score=-0.068 total time=  13.8s
# [CV 2/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=9, regressor__p=1, regressor__weights=distance;, score=-0.067 total time=  13.8s
# [CV 3/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=9, regressor__p=1, regressor__weights=distance;, score=-0.064 total time=  13.9s
# [CV 2/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=9, regressor__p=2, regressor__weights=distance;, score=-0.083 total time=   2.8s
# [CV 4/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=9, regressor__p=1, regressor__weights=distance;, score=-0.059 total time=  13.9s
# [CV 5/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=9, regressor__p=1, regressor__weights=distance;, score=-0.072 total time=  13.9s
# [CV 3/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=9, regressor__p=2, regressor__weights=distance;, score=-0.077 total time=   3.1s
# [CV 5/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=9, regressor__p=2, regressor__weights=distance;, score=-0.086 total time=   3.0s
# [CV 4/5] END regressor__algorithm=auto, regressor__leaf_size=20, regressor__n_neighbors=9, regressor__p=2, regressor__weights=distance;, score=-0.074 total time=   3.2s
# [CV 1/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=3, regressor__p=2, regressor__weights=uniform;, score=-0.082 total time=   2.9s
# [CV 2/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=3, regressor__p=2, regressor__weights=uniform;, score=-0.082 total time=   3.0s
# [CV 3/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=3, regressor__p=2, regressor__weights=uniform;, score=-0.077 total time=   2.9s
# [CV 4/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=3, regressor__p=2, regressor__weights=uniform;, score=-0.074 total time=   3.0s
# [CV 5/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=3, regressor__p=2, regressor__weights=uniform;, score=-0.090 total time=   3.1s
# [CV 1/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=3, regressor__p=2, regressor__weights=distance;, score=-0.075 total time=   3.1s
# [CV 1/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=3, regressor__p=1, regressor__weights=uniform;, score=-0.069 total time=  13.4s
# [CV 2/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=3, regressor__p=1, regressor__weights=uniform;, score=-0.070 total time=  13.4s
# [CV 3/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=3, regressor__p=1, regressor__weights=uniform;, score=-0.067 total time=  13.7s
# [CV 4/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=3, regressor__p=1, regressor__weights=uniform;, score=-0.062 total time=  13.6s
# [CV 5/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=3, regressor__p=1, regressor__weights=uniform;, score=-0.076 total time=  13.7s
# [CV 1/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=3, regressor__p=1, regressor__weights=distance;, score=-0.064 total time=  13.6s
# [CV 4/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=3, regressor__p=1, regressor__weights=distance;, score=-0.056 total time=  13.2s
# [CV 3/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=3, regressor__p=1, regressor__weights=distance;, score=-0.061 total time=  13.3s
# [CV 2/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=3, regressor__p=2, regressor__weights=distance;, score=-0.075 total time=   2.9s
# [CV 2/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=3, regressor__p=1, regressor__weights=distance;, score=-0.064 total time=  13.9s
# [CV 3/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=3, regressor__p=2, regressor__weights=distance;, score=-0.071 total time=   3.0s
# [CV 5/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=3, regressor__p=1, regressor__weights=distance;, score=-0.072 total time=  13.6s
# [CV 4/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=3, regressor__p=2, regressor__weights=distance;, score=-0.067 total time=   3.0s
# [CV 5/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=3, regressor__p=2, regressor__weights=distance;, score=-0.085 total time=   3.0s
# [CV 1/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=5, regressor__p=2, regressor__weights=uniform;, score=-0.085 total time=   3.0s
# [CV 2/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=5, regressor__p=2, regressor__weights=uniform;, score=-0.087 total time=   3.0s
# [CV 3/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=5, regressor__p=2, regressor__weights=uniform;, score=-0.082 total time=   2.9s
# [CV 4/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=5, regressor__p=2, regressor__weights=uniform;, score=-0.079 total time=   3.0s
# [CV 5/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=5, regressor__p=2, regressor__weights=uniform;, score=-0.092 total time=   3.0s
# [CV 1/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=5, regressor__p=2, regressor__weights=distance;, score=-0.075 total time=   3.0s
# [CV 1/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=5, regressor__p=1, regressor__weights=uniform;, score=-0.074 total time=  13.7s
# [CV 2/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=5, regressor__p=1, regressor__weights=uniform;, score=-0.075 total time=  13.8s
# [CV 3/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=5, regressor__p=1, regressor__weights=uniform;, score=-0.068 total time=  13.5s
# [CV 4/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=5, regressor__p=1, regressor__weights=uniform;, score=-0.066 total time=  13.5s
# [CV 5/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=5, regressor__p=1, regressor__weights=uniform;, score=-0.077 total time=  13.5s
# [CV 1/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=5, regressor__p=1, regressor__weights=distance;, score=-0.065 total time=  13.6s
# [CV 2/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=5, regressor__p=2, regressor__weights=distance;, score=-0.075 total time=   3.0s
# [CV 3/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=5, regressor__p=2, regressor__weights=distance;, score=-0.073 total time=   3.0s
# [CV 2/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=5, regressor__p=1, regressor__weights=distance;, score=-0.064 total time=  13.9s
# [CV 4/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=5, regressor__p=1, regressor__weights=distance;, score=-0.056 total time=  13.5s
# [CV 5/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=5, regressor__p=1, regressor__weights=distance;, score=-0.071 total time=  13.3s
# [CV 3/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=5, regressor__p=1, regressor__weights=distance;, score=-0.060 total time=  13.8s
# [CV 4/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=5, regressor__p=2, regressor__weights=distance;, score=-0.068 total time=   2.9s
# [CV 5/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=5, regressor__p=2, regressor__weights=distance;, score=-0.084 total time=   2.8s
# [CV 2/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=7, regressor__p=2, regressor__weights=uniform;, score=-0.094 total time=   2.8s
# [CV 1/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=7, regressor__p=2, regressor__weights=uniform;, score=-0.089 total time=   3.0s
# [CV 4/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=7, regressor__p=2, regressor__weights=uniform;, score=-0.084 total time=   2.8s
# [CV 3/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=7, regressor__p=2, regressor__weights=uniform;, score=-0.085 total time=   2.9s
# [CV 5/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=7, regressor__p=2, regressor__weights=uniform;, score=-0.095 total time=   3.0s
# [CV 1/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=7, regressor__p=2, regressor__weights=distance;, score=-0.077 total time=   3.0s
# [CV 4/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=7, regressor__p=1, regressor__weights=uniform;, score=-0.070 total time=  13.0s
# [CV 3/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=7, regressor__p=1, regressor__weights=uniform;, score=-0.072 total time=  13.2s
# [CV 2/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=7, regressor__p=1, regressor__weights=uniform;, score=-0.079 total time=  13.4s
# [CV 1/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=7, regressor__p=1, regressor__weights=uniform;, score=-0.077 total time=  13.6s
# [CV 5/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=7, regressor__p=1, regressor__weights=uniform;, score=-0.079 total time=  13.3s
# [CV 2/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=7, regressor__p=1, regressor__weights=distance;, score=-0.065 total time=  13.1s
# [CV 1/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=7, regressor__p=1, regressor__weights=distance;, score=-0.066 total time=  13.2s
# [CV 5/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=7, regressor__p=1, regressor__weights=distance;, score=-0.071 total time=  13.2s
# [CV 3/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=7, regressor__p=1, regressor__weights=distance;, score=-0.062 total time=  13.4s
# [CV 4/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=7, regressor__p=1, regressor__weights=distance;, score=-0.058 total time=  13.5s
# [CV 2/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=7, regressor__p=2, regressor__weights=distance;, score=-0.079 total time=   3.0s
# [CV 3/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=7, regressor__p=2, regressor__weights=distance;, score=-0.074 total time=   3.0s
# [CV 4/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=7, regressor__p=2, regressor__weights=distance;, score=-0.071 total time=   3.1s
# [CV 5/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=7, regressor__p=2, regressor__weights=distance;, score=-0.085 total time=   3.0s
# [CV 1/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=9, regressor__p=2, regressor__weights=uniform;, score=-0.093 total time=   2.9s
# [CV 2/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=9, regressor__p=2, regressor__weights=uniform;, score=-0.100 total time=   3.0s
# [CV 3/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=9, regressor__p=2, regressor__weights=uniform;, score=-0.089 total time=   2.8s
# [CV 4/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=9, regressor__p=2, regressor__weights=uniform;, score=-0.090 total time=   3.1s
# [CV 5/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=9, regressor__p=2, regressor__weights=uniform;, score=-0.098 total time=   3.2s
# [CV 1/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=9, regressor__p=2, regressor__weights=distance;, score=-0.080 total time=   3.2s
# [CV 2/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=9, regressor__p=1, regressor__weights=uniform;, score=-0.082 total time=  13.4s
# [CV 1/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=9, regressor__p=1, regressor__weights=uniform;, score=-0.080 total time=  13.8s
# [CV 4/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=9, regressor__p=1, regressor__weights=uniform;, score=-0.074 total time=  13.5s
# [CV 3/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=9, regressor__p=1, regressor__weights=uniform;, score=-0.075 total time=  13.7s
# [CV 2/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=9, regressor__p=1, regressor__weights=distance;, score=-0.067 total time=  13.5s
# [CV 1/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=9, regressor__p=1, regressor__weights=distance;, score=-0.068 total time=  13.6s
# [CV 5/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=9, regressor__p=1, regressor__weights=uniform;, score=-0.081 total time=  13.8s
# [CV 3/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=9, regressor__p=1, regressor__weights=distance;, score=-0.064 total time=  13.6s
# [CV 4/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=9, regressor__p=1, regressor__weights=distance;, score=-0.059 total time=  13.5s
# [CV 5/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=9, regressor__p=1, regressor__weights=distance;, score=-0.072 total time=  13.7s
# [CV 2/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=9, regressor__p=2, regressor__weights=distance;, score=-0.083 total time=   3.1s
# [CV 3/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=9, regressor__p=2, regressor__weights=distance;, score=-0.077 total time=   3.3s
# [CV 4/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=9, regressor__p=2, regressor__weights=distance;, score=-0.074 total time=   3.1s
# [CV 5/5] END regressor__algorithm=auto, regressor__leaf_size=30, regressor__n_neighbors=9, regressor__p=2, regressor__weights=distance;, score=-0.086 total time=   3.0s
# [CV 1/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=3, regressor__p=2, regressor__weights=uniform;, score=-0.082 total time=   3.0s
# [CV 2/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=3, regressor__p=2, regressor__weights=uniform;, score=-0.082 total time=   3.0s
# [CV 3/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=3, regressor__p=2, regressor__weights=uniform;, score=-0.077 total time=   3.0s
# [CV 4/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=3, regressor__p=2, regressor__weights=uniform;, score=-0.074 total time=   3.0s
# [CV 5/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=3, regressor__p=2, regressor__weights=uniform;, score=-0.090 total time=   3.0s
# [CV 1/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=3, regressor__p=2, regressor__weights=distance;, score=-0.075 total time=   3.0s
# [CV 2/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=3, regressor__p=1, regressor__weights=uniform;, score=-0.070 total time=  13.6s
# [CV 1/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=3, regressor__p=1, regressor__weights=uniform;, score=-0.069 total time=  13.6s
# [CV 3/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=3, regressor__p=1, regressor__weights=uniform;, score=-0.067 total time=  13.5s
# [CV 5/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=3, regressor__p=1, regressor__weights=uniform;, score=-0.076 total time=  13.4s
# [CV 1/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=3, regressor__p=1, regressor__weights=distance;, score=-0.064 total time=  13.6s
# [CV 4/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=3, regressor__p=1, regressor__weights=uniform;, score=-0.062 total time=  13.8s
# [CV 2/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=3, regressor__p=1, regressor__weights=distance;, score=-0.064 total time=  13.8s
# [CV 3/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=3, regressor__p=1, regressor__weights=distance;, score=-0.061 total time=  13.7s
# [CV 2/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=3, regressor__p=2, regressor__weights=distance;, score=-0.075 total time=   2.9s
# [CV 4/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=3, regressor__p=1, regressor__weights=distance;, score=-0.056 total time=  13.7s
# [CV 3/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=3, regressor__p=2, regressor__weights=distance;, score=-0.071 total time=   3.0s
# [CV 5/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=3, regressor__p=1, regressor__weights=distance;, score=-0.072 total time=  13.5s
# [CV 4/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=3, regressor__p=2, regressor__weights=distance;, score=-0.067 total time=   2.9s
# [CV 5/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=3, regressor__p=2, regressor__weights=distance;, score=-0.085 total time=   3.0s
# [CV 1/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=5, regressor__p=2, regressor__weights=uniform;, score=-0.085 total time=   2.9s
# [CV 2/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=5, regressor__p=2, regressor__weights=uniform;, score=-0.087 total time=   2.9s
# [CV 3/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=5, regressor__p=2, regressor__weights=uniform;, score=-0.082 total time=   2.9s
# [CV 4/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=5, regressor__p=2, regressor__weights=uniform;, score=-0.079 total time=   3.0s
# [CV 5/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=5, regressor__p=2, regressor__weights=uniform;, score=-0.092 total time=   2.8s
# [CV 1/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=5, regressor__p=2, regressor__weights=distance;, score=-0.075 total time=   2.9s
# [CV 1/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=5, regressor__p=1, regressor__weights=uniform;, score=-0.074 total time=  13.5s
# [CV 3/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=5, regressor__p=1, regressor__weights=uniform;, score=-0.068 total time=  13.2s
# [CV 4/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=5, regressor__p=1, regressor__weights=uniform;, score=-0.066 total time=  13.2s
# [CV 2/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=5, regressor__p=1, regressor__weights=uniform;, score=-0.075 total time=  13.5s
# [CV 5/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=5, regressor__p=1, regressor__weights=uniform;, score=-0.077 total time=  13.3s
# [CV 2/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=5, regressor__p=1, regressor__weights=distance;, score=-0.064 total time=  13.1s
# [CV 1/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=5, regressor__p=1, regressor__weights=distance;, score=-0.065 total time=  13.3s
# [CV 3/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=5, regressor__p=1, regressor__weights=distance;, score=-0.060 total time=  13.3s
# [CV 2/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=5, regressor__p=2, regressor__weights=distance;, score=-0.075 total time=   2.9s
# [CV 3/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=5, regressor__p=2, regressor__weights=distance;, score=-0.073 total time=   2.9s
# [CV 5/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=5, regressor__p=1, regressor__weights=distance;, score=-0.071 total time=  13.2s
# [CV 4/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=5, regressor__p=1, regressor__weights=distance;, score=-0.056 total time=  13.5s
# [CV 4/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=5, regressor__p=2, regressor__weights=distance;, score=-0.068 total time=   2.8s
# [CV 5/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=5, regressor__p=2, regressor__weights=distance;, score=-0.084 total time=   2.9s
# [CV 1/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=7, regressor__p=2, regressor__weights=uniform;, score=-0.089 total time=   2.8s
# [CV 2/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=7, regressor__p=2, regressor__weights=uniform;, score=-0.094 total time=   2.8s
# [CV 3/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=7, regressor__p=2, regressor__weights=uniform;, score=-0.085 total time=   3.0s
# [CV 4/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=7, regressor__p=2, regressor__weights=uniform;, score=-0.084 total time=   3.2s
# [CV 5/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=7, regressor__p=2, regressor__weights=uniform;, score=-0.095 total time=   3.1s
# [CV 1/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=7, regressor__p=2, regressor__weights=distance;, score=-0.077 total time=   2.9s
# [CV 2/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=7, regressor__p=1, regressor__weights=uniform;, score=-0.079 total time=  13.2s
# [CV 1/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=7, regressor__p=1, regressor__weights=uniform;, score=-0.077 total time=  13.5s
# [CV 4/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=7, regressor__p=1, regressor__weights=uniform;, score=-0.070 total time=  13.3s
# [CV 1/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=7, regressor__p=1, regressor__weights=distance;, score=-0.066 total time=  13.0s
# [CV 5/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=7, regressor__p=1, regressor__weights=uniform;, score=-0.079 total time=  13.3s
# [CV 3/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=7, regressor__p=1, regressor__weights=uniform;, score=-0.072 total time=  13.5s
# [CV 2/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=7, regressor__p=1, regressor__weights=distance;, score=-0.065 total time=  13.2s
# [CV 3/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=7, regressor__p=1, regressor__weights=distance;, score=-0.062 total time=  13.2s
# [CV 5/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=7, regressor__p=1, regressor__weights=distance;, score=-0.071 total time=  13.3s
# [CV 2/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=7, regressor__p=2, regressor__weights=distance;, score=-0.079 total time=   2.9s
# [CV 3/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=7, regressor__p=2, regressor__weights=distance;, score=-0.074 total time=   3.0s
# [CV 4/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=7, regressor__p=1, regressor__weights=distance;, score=-0.058 total time=  13.8s
# [CV 4/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=7, regressor__p=2, regressor__weights=distance;, score=-0.071 total time=   2.8s
# [CV 5/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=7, regressor__p=2, regressor__weights=distance;, score=-0.085 total time=   3.0s
# [CV 1/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=9, regressor__p=2, regressor__weights=uniform;, score=-0.093 total time=   3.0s
# [CV 2/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=9, regressor__p=2, regressor__weights=uniform;, score=-0.100 total time=   2.9s
# [CV 3/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=9, regressor__p=2, regressor__weights=uniform;, score=-0.089 total time=   2.9s
# [CV 4/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=9, regressor__p=2, regressor__weights=uniform;, score=-0.090 total time=   2.9s
# [CV 5/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=9, regressor__p=2, regressor__weights=uniform;, score=-0.098 total time=   2.9s
# [CV 1/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=9, regressor__p=2, regressor__weights=distance;, score=-0.080 total time=   3.0s
# [CV 5/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=9, regressor__p=1, regressor__weights=uniform;, score=-0.081 total time=  12.9s
# [CV 1/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=9, regressor__p=1, regressor__weights=uniform;, score=-0.080 total time=  13.3s
# [CV 2/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=9, regressor__p=1, regressor__weights=uniform;, score=-0.082 total time=  13.3s
# [CV 3/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=9, regressor__p=1, regressor__weights=uniform;, score=-0.075 total time=  13.3s
# [CV 4/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=9, regressor__p=1, regressor__weights=uniform;, score=-0.074 total time=  13.3s
# [CV 1/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=9, regressor__p=1, regressor__weights=distance;, score=-0.068 total time=  13.3s
# [CV 3/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=9, regressor__p=1, regressor__weights=distance;, score=-0.064 total time=  13.1s
# [CV 2/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=9, regressor__p=1, regressor__weights=distance;, score=-0.067 total time=  13.3s
# [CV 4/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=9, regressor__p=1, regressor__weights=distance;, score=-0.059 total time=  13.2s
# [CV 2/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=9, regressor__p=2, regressor__weights=distance;, score=-0.083 total time=   3.0s
# [CV 5/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=9, regressor__p=1, regressor__weights=distance;, score=-0.072 total time=  13.1s
# [CV 3/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=9, regressor__p=2, regressor__weights=distance;, score=-0.077 total time=   3.0s
# [CV 4/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=9, regressor__p=2, regressor__weights=distance;, score=-0.074 total time=   3.0s
# [CV 5/5] END regressor__algorithm=auto, regressor__leaf_size=40, regressor__n_neighbors=9, regressor__p=2, regressor__weights=distance;, score=-0.086 total time=   3.0s
# [CV 2/5] END regressor__algorithm=auto, regressor__leaf_size=50, regressor__n_neighbors=3, regressor__p=2, regressor__weights=uniform;, score=-0.082 total time=   2.9s
# [CV 1/5] END regressor__algorithm=auto, regressor__leaf_size=50, regressor__n_neighbors=3, regressor__p=2, regressor__weights=uniform;, score=-0.082 total time=   3.0s
# [CV 3/5] END regressor__algorithm=auto, regressor__leaf_size=50, regressor__n_neighbors=3, regressor__p=2, regressor__weights=uniform;, score=-0.077 total time=   2.8s
# [CV 4/5] END regressor__algorithm=auto, regressor__leaf_size=50, regressor__n_neighbors=3, regressor__p=2, regressor__weights=uniform;, score=-0.074 total time=   3.0s
# [CV 5/5] END regressor__algorithm=auto, regressor__leaf_size=50, regressor__n_neighbors=3, regressor__p=2, regressor__weights=uniform;, score=-0.090 total time=   2.9s
# [CV 1/5] END regressor__algorithm=auto, regressor__leaf_size=50, regressor__n_neighbors=3, regressor__p=2, regressor__weights=distance;, score=-0.075 total time=   2.9s
# [CV 3/5] END regressor__algorithm=auto, regressor__leaf_size=50, regressor__n_neighbors=3, regressor__p=1, regressor__weights=uniform;, score=-0.067 total time=  13.1s
# [CV 2/5] END regressor__algorithm=auto, regressor__leaf_size=50, regressor__n_neighbors=3, regressor__p=1, regressor__weights=uniform;, score=-0.070 total time=  13.2s
# [CV 1/5] END regressor__algorithm=auto, regressor__leaf_size=50, regressor__n_neighbors=3, regressor__p=1, regressor__weights=uniform;, score=-0.069 total time=  13.3s
# [CV 1/5] END regressor__algorithm=auto, regressor__leaf_size=50, regressor__n_neighbors=3, regressor__p=1, regressor__weights=distance;, score=-0.064 total time=  12.9s
# [CV 4/5] END regressor__algorithm=auto, regressor__leaf_size=50, regressor__n_neighbors=3, regressor__p=1, regressor__weights=uniform;, score=-0.062 total time=  13.4s
# [CV 5/5] END regressor__algorithm=auto, regressor__leaf_size=50, regressor__n_neighbors=3, regressor__p=1, regressor__weights=uniform;, score=-0.076 total time=  13.4s
# [CV 2/5] END regressor__algorithm=auto, regressor__leaf_size=50, regressor__n_neighbors=3, regressor__p=1, regressor__weights=distance;, score=-0.064 total time=  13.1s
# [CV 4/5] END regressor__algorithm=auto, regressor__leaf_size=50, regressor__n_neighbors=3, regressor__p=1, regressor__weights=distance;, score=-0.056 total time=  13.1s
# [CV 3/5] END regressor__algorithm=auto, regressor__leaf_size=50, regressor__n_neighbors=3, regressor__p=1, regressor__weights=distance;, score=-0.061 total time=  13.5s
# [CV 2/5] END regressor__algorithm=auto, regressor__leaf_size=50, regressor__n_neighbors=3, regressor__p=2, regressor__weights=distance;, score=-0.075 total time=   3.0s
# [CV 3/5] END regressor__algorithm=auto, regressor__leaf_size=50, regressor__n_neighbors=3, regressor__p=2, regressor__weights=distance;, score=-0.071 total time=   2.9s
# [CV 5/5] END regressor__algorithm=auto, regressor__leaf_size=50, regressor__n_neighbors=3, regressor__p=1, regressor__weights=distance;, score=-0.072 total time=  13.5s
# [CV 4/5] END regressor__algorithm=auto, regressor__leaf_size=50, regressor__n_neighbors=3, regressor__p=2, regressor__weights=distance;, score=-0.067 total time=   2.9s
# [CV 5/5] END regressor__algorithm=auto, regressor__leaf_size=50, regressor__n_neighbors=3, regressor__p=2, regressor__weights=distance;, score=-0.085 total time=   2.9s
# [CV 1/5] END regressor__algorithm=auto, regressor__leaf_size=50, regressor__n_neighbors=5, regressor__p=2, regressor__weights=uniform;, score=-0.085 total time=   2.9s
# [CV 2/5] END regressor__algorithm=auto, regressor__leaf_size=50, regressor__n_neighbors=5, regressor__p=2, regressor__weights=uniform;, score=-0.087 total time=   2.8s
# [CV 4/5] END regressor__algorithm=auto, regressor__leaf_size=50, regressor__n_neighbors=5, regressor__p=2, regressor__weights=uniform;, score=-0.079 total time=   2.8s
# [CV 3/5] END regressor__algorithm=auto, regressor__leaf_size=50, regressor__n_neighbors=5, regressor__p=2, regressor__weights=uniform;, score=-0.082 total time=   3.1s
# [CV 5/5] END regressor__algorithm=auto, regressor__leaf_size=50, regressor__n_neighbors=5, regressor__p=2, regressor__weights=uniform;, score=-0.092 total time=   3.0s
# [CV 1/5] END regressor__algorithm=auto, regressor__leaf_size=50, regressor__n_neighbors=5, regressor__p=2, regressor__weights=distance;, score=-0.075 total time=   3.0s
# [CV 1/5] END regressor__algorithm=auto, regressor__leaf_size=50, regressor__n_neighbors=5, regressor__p=1, regressor__weights=uniform;, score=-0.074 total time=  13.3s
# [CV 2/5] END regressor__algorithm=auto, regressor__leaf_size=50, regressor__n_neighbors=5, regressor__p=1, regressor__weights=uniform;, score=-0.075 total time=  13.1s
# [CV 4/5] END regressor__algorithm=auto, regressor__leaf_size=50, regressor__n_neighbors=5, regressor__p=1, regressor__weights=uniform;, score=-0.066 total time=  13.1s
# [CV 5/5] END regressor__algorithm=auto, regressor__leaf_size=50, regressor__n_neighbors=5, regressor__p=1, regressor__weights=uniform;, score=-0.077 total time=  13.2s
# [CV 3/5] END regressor__algorithm=auto, regressor__leaf_size=50, regressor__n_neighbors=5, regressor__p=1, regressor__weights=uniform;, score=-0.068 total time=  13.4s
# [CV 1/5] END regressor__algorithm=auto, regressor__leaf_size=50, regressor__n_neighbors=5, regressor__p=1, regressor__weights=distance;, score=-0.065 total time=  13.3s
# [CV 2/5] END regressor__algorithm=auto, regressor__leaf_size=50, regressor__n_neighbors=5, regressor__p=1, regressor__weights=distance;, score=-0.064 total time=  13.2s
# [CV 3/5] END regressor__algorithm=auto, regressor__leaf_size=50, regressor__n_neighbors=5, regressor__p=1, regressor__weights=distance;, score=-0.060 total time=  13.0s
# [CV 2/5] END regressor__algorithm=auto, regressor__leaf_size=50, regressor__n_neighbors=5, regressor__p=2, regressor__weights=distance;, score=-0.075 total time=   2.9s
# [CV 4/5] END regressor__algorithm=auto, regressor__leaf_size=50, regressor__n_neighbors=5, regressor__p=1, regressor__weights=distance;, score=-0.056 total time=  13.1s
# [CV 5/5] END regressor__algorithm=auto, regressor__leaf_size=50, regressor__n_neighbors=5, regressor__p=1, regressor__weights=distance;, score=-0.071 total time=  13.2s
# ...
# [CV 1/5] END regressor__algorithm=brute, regressor__leaf_size=40, regressor__n_neighbors=9, regressor__p=1, regressor__weights=distance;, score=-0.068 total time=  13.1s
# [CV 4/5] END regressor__algorithm=brute, regressor__leaf_size=40, regressor__n_neighbors=9, regressor__p=1, regressor__weights=uniform;, score=-0.074 total time=  13.4s
# [CV 5/5] END regressor__algorithm=brute, regressor__leaf_size=40, regressor__n_neighbors=9, regressor__p=1, regressor__weights=uniform;, score=-0.081 total time=  13.4s
# [CV 2/5] END regressor__algorithm=brute, regressor__leaf_size=40, regressor__n_neighbors=9, regressor__p=1, regressor__weights=distance;, score=-0.067 total time=  13.3s
# [CV 3/5] END regressor__algorithm=brute, regressor__leaf_size=40, regressor__n_neighbors=9, regressor__p=1, regressor__weights=distance;, score=-0.064 total time=  13.5s
# [CV 4/5] END regressor__algorithm=brute, regressor__leaf_size=40, regressor__n_neighbors=9, regressor__p=1, regressor__weights=distance;, score=-0.059 total time=  13.3s
# [CV 2/5] END regressor__algorithm=brute, regressor__leaf_size=40, regressor__n_neighbors=9, regressor__p=2, regressor__weights=distance;, score=-0.083 total time=   3.0s
# [CV 3/5] END regressor__algorithm=brute, regressor__leaf_size=40, regressor__n_neighbors=9, regressor__p=2, regressor__weights=distance;, score=-0.077 total time=   3.0s
# [CV 5/5] END regressor__algorithm=brute, regressor__leaf_size=40, regressor__n_neighbors=9, regressor__p=1, regressor__weights=distance;, score=-0.072 total time=  13.6s
# [CV 4/5] END regressor__algorithm=brute, regressor__leaf_size=40, regressor__n_neighbors=9, regressor__p=2, regressor__weights=distance;, score=-0.074 total time=   2.9s
# [CV 5/5] END regressor__algorithm=brute, regressor__leaf_size=40, regressor__n_neighbors=9, regressor__p=2, regressor__weights=distance;, score=-0.086 total time=   3.0s
# [CV 1/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=3, regressor__p=2, regressor__weights=uniform;, score=-0.082 total time=   3.0s
# [CV 2/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=3, regressor__p=2, regressor__weights=uniform;, score=-0.082 total time=   3.0s
# [CV 3/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=3, regressor__p=2, regressor__weights=uniform;, score=-0.077 total time=   2.9s
# [CV 4/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=3, regressor__p=2, regressor__weights=uniform;, score=-0.074 total time=   2.8s
# [CV 5/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=3, regressor__p=2, regressor__weights=uniform;, score=-0.090 total time=   2.9s
# [CV 1/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=3, regressor__p=2, regressor__weights=distance;, score=-0.075 total time=   3.0s
# [CV 1/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=3, regressor__p=1, regressor__weights=uniform;, score=-0.069 total time=  13.2s
# [CV 2/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=3, regressor__p=1, regressor__weights=uniform;, score=-0.070 total time=  13.2s
# [CV 5/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=3, regressor__p=1, regressor__weights=uniform;, score=-0.076 total time=  13.3s
# [CV 3/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=3, regressor__p=1, regressor__weights=uniform;, score=-0.067 total time=  13.5s
# [CV 4/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=3, regressor__p=1, regressor__weights=uniform;, score=-0.062 total time=  13.6s
# [CV 1/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=3, regressor__p=1, regressor__weights=distance;, score=-0.064 total time=  13.6s
# [CV 2/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=3, regressor__p=1, regressor__weights=distance;, score=-0.064 total time=  13.6s
# [CV 2/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=3, regressor__p=2, regressor__weights=distance;, score=-0.075 total time=   2.9s
# [CV 3/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=3, regressor__p=1, regressor__weights=distance;, score=-0.061 total time=  13.4s
# [CV 4/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=3, regressor__p=1, regressor__weights=distance;, score=-0.056 total time=  13.3s
# [CV 3/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=3, regressor__p=2, regressor__weights=distance;, score=-0.071 total time=   3.0s
# [CV 5/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=3, regressor__p=1, regressor__weights=distance;, score=-0.072 total time=  13.4s
# [CV 4/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=3, regressor__p=2, regressor__weights=distance;, score=-0.067 total time=   3.1s
# [CV 5/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=3, regressor__p=2, regressor__weights=distance;, score=-0.085 total time=   3.0s
# [CV 1/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=5, regressor__p=2, regressor__weights=uniform;, score=-0.085 total time=   2.9s
# [CV 2/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=5, regressor__p=2, regressor__weights=uniform;, score=-0.087 total time=   2.9s
# [CV 3/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=5, regressor__p=2, regressor__weights=uniform;, score=-0.082 total time=   3.0s
# [CV 4/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=5, regressor__p=2, regressor__weights=uniform;, score=-0.079 total time=   3.0s
# [CV 5/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=5, regressor__p=2, regressor__weights=uniform;, score=-0.092 total time=   2.8s
# [CV 1/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=5, regressor__p=2, regressor__weights=distance;, score=-0.075 total time=   3.0s
# [CV 2/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=5, regressor__p=1, regressor__weights=uniform;, score=-0.075 total time=  13.3s
# [CV 1/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=5, regressor__p=1, regressor__weights=uniform;, score=-0.074 total time=  13.5s
# [CV 3/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=5, regressor__p=1, regressor__weights=uniform;, score=-0.068 total time=  13.4s
# [CV 1/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=5, regressor__p=1, regressor__weights=distance;, score=-0.065 total time=  13.2s
# [CV 5/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=5, regressor__p=1, regressor__weights=uniform;, score=-0.077 total time=  13.3s
# [CV 4/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=5, regressor__p=1, regressor__weights=uniform;, score=-0.066 total time=  13.5s
# [CV 3/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=5, regressor__p=1, regressor__weights=distance;, score=-0.060 total time=  13.5s
# [CV 4/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=5, regressor__p=1, regressor__weights=distance;, score=-0.056 total time=  13.3s
# [CV 2/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=5, regressor__p=2, regressor__weights=distance;, score=-0.075 total time=   2.9s
# [CV 2/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=5, regressor__p=1, regressor__weights=distance;, score=-0.064 total time=  13.7s
# [CV 5/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=5, regressor__p=1, regressor__weights=distance;, score=-0.071 total time=  13.6s
# [CV 3/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=5, regressor__p=2, regressor__weights=distance;, score=-0.073 total time=   3.1s
# [CV 4/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=5, regressor__p=2, regressor__weights=distance;, score=-0.068 total time=   3.0s
# [CV 5/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=5, regressor__p=2, regressor__weights=distance;, score=-0.084 total time=   2.9s
# [CV 2/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=7, regressor__p=2, regressor__weights=uniform;, score=-0.094 total time=   2.8s
# [CV 1/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=7, regressor__p=2, regressor__weights=uniform;, score=-0.089 total time=   3.0s
# [CV 3/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=7, regressor__p=2, regressor__weights=uniform;, score=-0.085 total time=   3.0s
# [CV 4/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=7, regressor__p=2, regressor__weights=uniform;, score=-0.084 total time=   2.9s
# [CV 1/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=7, regressor__p=2, regressor__weights=distance;, score=-0.077 total time=   2.9s
# [CV 5/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=7, regressor__p=2, regressor__weights=uniform;, score=-0.095 total time=   3.0s
# [CV 1/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=7, regressor__p=1, regressor__weights=uniform;, score=-0.077 total time=  13.6s
# [CV 2/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=7, regressor__p=1, regressor__weights=uniform;, score=-0.079 total time=  13.5s
# [CV 3/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=7, regressor__p=1, regressor__weights=uniform;, score=-0.072 total time=  13.6s
# [CV 4/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=7, regressor__p=1, regressor__weights=uniform;, score=-0.070 total time=  13.5s
# [CV 1/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=7, regressor__p=1, regressor__weights=distance;, score=-0.066 total time=  13.5s
# [CV 2/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=7, regressor__p=1, regressor__weights=distance;, score=-0.065 total time=  13.5s
# [CV 5/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=7, regressor__p=1, regressor__weights=uniform;, score=-0.079 total time=  13.7s
# [CV 3/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=7, regressor__p=1, regressor__weights=distance;, score=-0.062 total time=  13.5s
# [CV 4/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=7, regressor__p=1, regressor__weights=distance;, score=-0.058 total time=  13.5s
# [CV 5/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=7, regressor__p=1, regressor__weights=distance;, score=-0.071 total time=  13.5s
# [CV 2/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=7, regressor__p=2, regressor__weights=distance;, score=-0.079 total time=   3.0s
# [CV 3/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=7, regressor__p=2, regressor__weights=distance;, score=-0.074 total time=   3.1s
# [CV 4/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=7, regressor__p=2, regressor__weights=distance;, score=-0.071 total time=   3.0s
# [CV 5/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=7, regressor__p=2, regressor__weights=distance;, score=-0.085 total time=   3.1s
# [CV 1/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=9, regressor__p=2, regressor__weights=uniform;, score=-0.093 total time=   2.9s
# [CV 2/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=9, regressor__p=2, regressor__weights=uniform;, score=-0.100 total time=   2.9s
# [CV 3/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=9, regressor__p=2, regressor__weights=uniform;, score=-0.089 total time=   3.0s
# [CV 4/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=9, regressor__p=2, regressor__weights=uniform;, score=-0.090 total time=   3.0s
# [CV 5/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=9, regressor__p=2, regressor__weights=uniform;, score=-0.098 total time=   3.0s
# [CV 1/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=9, regressor__p=2, regressor__weights=distance;, score=-0.080 total time=   3.0s
# [CV 2/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=9, regressor__p=1, regressor__weights=uniform;, score=-0.082 total time=  13.5s
# [CV 1/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=9, regressor__p=1, regressor__weights=uniform;, score=-0.080 total time=  13.7s
# [CV 3/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=9, regressor__p=1, regressor__weights=distance;, score=-0.064 total time=  13.2s
# [CV 3/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=9, regressor__p=1, regressor__weights=uniform;, score=-0.075 total time=  13.7s
# [CV 5/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=9, regressor__p=1, regressor__weights=uniform;, score=-0.081 total time=  13.6s
# [CV 1/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=9, regressor__p=1, regressor__weights=distance;, score=-0.068 total time=  13.5s
# [CV 4/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=9, regressor__p=1, regressor__weights=uniform;, score=-0.074 total time=  13.7s
# [CV 2/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=9, regressor__p=1, regressor__weights=distance;, score=-0.067 total time=  13.4s
# [CV 5/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=9, regressor__p=1, regressor__weights=distance;, score=-0.072 total time=  13.4s
# [CV 4/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=9, regressor__p=1, regressor__weights=distance;, score=-0.059 total time=  13.5s
# [CV 2/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=9, regressor__p=2, regressor__weights=distance;, score=-0.083 total time=   2.8s
# [CV 3/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=9, regressor__p=2, regressor__weights=distance;, score=-0.077 total time=   2.8s
# [CV 4/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=9, regressor__p=2, regressor__weights=distance;, score=-0.074 total time=   2.2s
# [CV 5/5] END regressor__algorithm=brute, regressor__leaf_size=50, regressor__n_neighbors=9, regressor__p=2, regressor__weights=distance;, score=-0.086 total time=   2.2s
# Best: -0.063117 using {'regressor__algorithm': 'kd_tree', 'regressor__leaf_size': 30, 'regressor__n_neighbors': 5, 'regressor__p': 1, 'regressor__weights': 'distance'}
# MAE: 0.11940928222403566
# RMSE: 0.2505727701729216
# R2: 0.9459262891900505
# /Users/sara/.pyenv/versions/3.10.0/envs/yao_project/lib/python3.10/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
best_knn
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('regressor',
#                  KNeighborsRegressor(algorithm='kd_tree', n_jobs=-1, p=1,
#                                      weights='distance'))])
